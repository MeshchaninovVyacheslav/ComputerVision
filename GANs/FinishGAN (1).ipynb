# %%
# %tensorflow_version  1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# # Generative Adversarial Networks
#
# Generative Adversarial Networks (GANs) are an approach to generative modeling based on deep learning methods.
#
# The standard problem settings for GANs are generation of photorealistic images and image-to-image translation tasks (translating photos of summer to winter, day to night etc.).
#
# In this task you will familiarize yourself with both these problems while trying to create fake images of sneakers.
#
# As GANs still do have certain limitations about generating large images, the task is decomposed into two: first, use a simple GAN to generate a bunch of low resolution images from noise, then upscale them using another generative model.

# %%
import os
import tqdm
import cv2
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
# %matplotlib inline

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import keras
L = keras.layers
K = keras.backend
# Out:
# Using TensorFlow backend.

# %%
# !wget "https://www.dropbox.com/s/7dnwfvqxstr3j4v/data.zip?dl=0" -O data.zip
# !unzip data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/images/01256.jpg
#   inflating: data/images/01639.jpg
#   inflating: data/images/00588.jpg
#   inflating: data/images/01532.jpg
#   inflating: data/images/01315.jpg
#   inflating: data/images/01110.jpg
#   inflating: data/images/00930.jpg
#   inflating: data/images/01815.jpg
#   inflating: data/images/01577.jpg
#   inflating: data/images/01582.jpg
#   inflating: data/images/01578.jpg
#   inflating: data/images/01378.jpg
#   inflating: data/images/00660.jpg
#   inflating: data/images/01593.jpg
#   inflating: data/images/01388.jpg
#   inflating: data/images/01200.jpg
#   inflating: data/images/01558.jpg
#   inflating: data/images/01479.jpg
#   inflating: data/images/01241.jpg
#   inflating: data/images/01176.jpg
#   inflating: data/images/00390.jpg
#   inflating: data/images/00722.jpg
#   inflating: data/images/01341.jpg
#   inflating: data/images/01193.jpg
#   inflating: data/images/02008.jpg
#   inflating: data/images/00978.jpg
#   inflating: data/images/01929.jpg
#   inflating: data/images/01040.jpg
#   inflating: data/images/00658.jpg
#   inflating: data/images/01584.jpg
#   inflating: data/images/01156.jpg
#   inflating: data/images/00724.jpg
#   inflating: data/images/01860.jpg
#   inflating: data/images/01083.jpg
#   inflating: data/images/00446.jpg
#   inflating: data/images/01904.jpg
#   inflating: data/images/01742.jpg
#   inflating: data/images/01443.jpg
#   inflating: data/images/01423.jpg
#   inflating: data/images/01489.jpg
#   inflating: data/images/01273.jpg
#   inflating: data/images/01735.jpg
#   inflating: data/images/02009.jpg
#   inflating: data/images/01703.jpg
#   inflating: data/images/01573.jpg
#   inflating: data/images/01626.jpg
#   inflating: data/images/01429.jpg
#   inflating: data/images/01229.jpg
#   inflating: data/images/01743.jpg
#   inflating: data/images/01799.jpg
#   inflating: data/images/00933.jpg
#   inflating: data/images/01966.jpg
#   inflating: data/images/01859.jpg
#   inflating: data/images/01804.jpg
#   inflating: data/images/01820.jpg
#   inflating: data/images/01079.jpg
#   inflating: data/images/01116.jpg
#   inflating: data/images/01438.jpg
#   inflating: data/images/01913.jpg
#   inflating: data/images/01634.jpg
#   inflating: data/images/01507.jpg
#   inflating: data/images/01606.jpg
#   inflating: data/images/00811.jpg
#   inflating: data/images/00410.jpg
#   inflating: data/images/01905.jpg
#   inflating: data/images/01418.jpg
#   inflating: data/images/02020.jpg
#   inflating: data/images/00981.jpg
#   inflating: data/images/01746.jpg
#   inflating: data/images/02045.jpg
#   inflating: data/images/01272.jpg
#   inflating: data/images/02061.jpg
#   inflating: data/images/01415.jpg
#   inflating: data/images/00428.jpg
#   inflating: data/images/02010.jpg
#   inflating: data/images/00406.jpg
#   inflating: data/images/01510.jpg
#   inflating: data/images/01728.jpg
#   inflating: data/images/02187.jpg
#   inflating: data/images/01936.jpg
#   inflating: data/images/02200.jpg
#   inflating: data/images/01263.jpg
#   inflating: data/images/02164.jpg
#   inflating: data/images/01724.jpg
#   inflating: data/images/02025.jpg
#   inflating: data/images/01138.jpg
#   inflating: data/images/01575.jpg
#   inflating: data/images/02183.jpg
#   inflating: data/images/01879.jpg
#   inflating: data/images/02137.jpg
#   inflating: data/images/01555.jpg
#   inflating: data/images/01419.jpg
#   inflating: data/images/01611.jpg
#   inflating: data/images/00770.jpg
#   inflating: data/images/01046.jpg
#   inflating: data/images/01874.jpg
#   inflating: data/images/01986.jpg
#   inflating: data/images/01719.jpg
#   inflating: data/images/00062.jpg
#   inflating: data/images/00730.jpg
#   inflating: data/images/01353.jpg
#   inflating: data/images/02181.jpg
#   inflating: data/images/01597.jpg
#   inflating: data/images/02044.jpg
#   inflating: data/images/01974.jpg
#   inflating: data/images/02023.jpg
#   inflating: data/images/01498.jpg
#   inflating: data/images/00489.jpg
#   inflating: data/images/00278.jpg
#   inflating: data/images/02066.jpg
#   inflating: data/images/02193.jpg
#   inflating: data/images/01034.jpg
#   inflating: data/images/01019.jpg
#   inflating: data/images/01907.jpg
#   inflating: data/images/01549.jpg
#   inflating: data/images/01717.jpg
#   inflating: data/images/01965.jpg
#   inflating: data/images/01134.jpg
#   inflating: data/images/00549.jpg
#   inflating: data/images/01506.jpg
#   inflating: data/images/01102.jpg
#   inflating: data/images/01837.jpg
#   inflating: data/images/02134.jpg
#   inflating: data/images/00196.jpg
#   inflating: data/images/01249.jpg
#   inflating: data/images/02042.jpg
#   inflating: data/images/00518.jpg
#   inflating: data/images/01099.jpg
#   inflating: data/images/02018.jpg
#   inflating: data/images/01309.jpg
#   inflating: data/images/02093.jpg
#   inflating: data/images/00934.jpg
#   inflating: data/images/02012.jpg
#   inflating: data/images/01579.jpg
#   inflating: data/images/01909.jpg
#   inflating: data/images/01537.jpg
#   inflating: data/images/02188.jpg
#   inflating: data/images/00759.jpg
#   inflating: data/images/01230.jpg
#   inflating: data/images/01207.jpg
#   inflating: data/images/01323.jpg
#   inflating: data/images/01955.jpg
#   inflating: data/images/01633.jpg
#   inflating: data/images/02050.jpg
#   inflating: data/images/00388.jpg
#   inflating: data/images/01925.jpg
#   inflating: data/images/01881.jpg
#   inflating: data/images/01282.jpg
#   inflating: data/images/02277.jpg
#   inflating: data/images/02309.jpg
#   inflating: data/images/02157.jpg
#   inflating: data/images/02340.jpg
#   inflating: data/images/01738.jpg
#   inflating: data/images/02207.jpg
#   inflating: data/images/02366.jpg
#   inflating: data/images/01563.jpg
#   inflating: data/images/01386.jpg
#   inflating: data/images/01710.jpg
#   inflating: data/images/01542.jpg
#   inflating: data/images/01580.jpg
#   inflating: data/images/01865.jpg
#   inflating: data/images/01502.jpg
#   inflating: data/images/00445.jpg
#   inflating: data/images/02013.jpg
#   inflating: data/images/02462.jpg
#   inflating: data/images/02170.jpg
#   inflating: data/images/00521.jpg
#   inflating: data/images/01567.jpg
#   inflating: data/images/01252.jpg
#   inflating: data/images/01996.jpg
#   inflating: data/images/02230.jpg
#   inflating: data/images/02030.jpg
#   inflating: data/images/02467.jpg
#   inflating: data/images/01144.jpg
#   inflating: data/images/02288.jpg
#   inflating: data/images/00550.jpg
#   inflating: data/images/01158.jpg
#   inflating: data/images/01867.jpg
#   inflating: data/images/00988.jpg
#   inflating: data/images/01968.jpg
#   inflating: data/images/01196.jpg
#   inflating: data/images/00152.jpg
#   inflating: data/images/01959.jpg
#   inflating: data/images/01560.jpg
#   inflating: data/images/01643.jpg
#   inflating: data/images/02203.jpg
#   inflating: data/images/01043.jpg
#   inflating: data/images/02436.jpg
#   inflating: data/images/01068.jpg
#   inflating: data/images/01589.jpg
#   inflating: data/images/02331.jpg
#   inflating: data/images/02222.jpg
#   inflating: data/images/02173.jpg
#   inflating: data/images/02192.jpg
#   inflating: data/images/01953.jpg
#   inflating: data/images/01157.jpg
#   inflating: data/images/02072.jpg
#   inflating: data/images/01839.jpg
#   inflating: data/images/01258.jpg
#   inflating: data/images/02269.jpg
#   inflating: data/images/01519.jpg
#   inflating: data/images/01711.jpg
#   inflating: data/images/02026.jpg
#   inflating: data/images/01379.jpg
#   inflating: data/images/01031.jpg
#   inflating: data/images/01592.jpg
#   inflating: data/images/02151.jpg
#   inflating: data/images/01871.jpg
#   inflating: data/images/01983.jpg
#   inflating: data/images/01009.jpg
#   inflating: data/images/01899.jpg
#   inflating: data/images/00807.jpg
#   inflating: data/images/02080.jpg
#   inflating: data/images/01795.jpg
#   inflating: data/images/02306.jpg
#   inflating: data/images/01038.jpg
#   inflating: data/images/01581.jpg
#   inflating: data/images/01835.jpg
#   inflating: data/images/01764.jpg
#   inflating: data/images/02390.jpg
#   inflating: data/images/01808.jpg
#   inflating: data/images/02274.jpg
#   inflating: data/images/01807.jpg
#   inflating: data/images/01453.jpg
#   inflating: data/images/01757.jpg
#   inflating: data/images/02324.jpg
#   inflating: data/images/01302.jpg
#   inflating: data/images/02394.jpg
#   inflating: data/images/01127.jpg
#   inflating: data/images/01956.jpg
#   inflating: data/images/02468.jpg
#   inflating: data/images/01568.jpg
#   inflating: data/images/01766.jpg
#   inflating: data/images/02507.jpg
#   inflating: data/images/01260.jpg
#   inflating: data/images/02370.jpg
#   inflating: data/images/02429.jpg
#   inflating: data/images/02091.jpg
#   inflating: data/images/02573.jpg
#   inflating: data/images/02561.jpg
#   inflating: data/images/02526.jpg
#   inflating: data/images/02554.jpg
#   inflating: data/images/01591.jpg
#   inflating: data/images/01794.jpg
#   inflating: data/images/02649.jpg
#   inflating: data/images/02082.jpg
#   inflating: data/images/01186.jpg
#   inflating: data/images/02689.jpg
#   inflating: data/images/00768.jpg
#   inflating: data/images/00562.jpg
#   inflating: data/images/02204.jpg
#   inflating: data/images/01086.jpg
#   inflating: data/images/02024.jpg
#   inflating: data/images/02375.jpg
#   inflating: data/images/00496.jpg
#   inflating: data/images/01208.jpg
#   inflating: data/images/01587.jpg
#   inflating: data/images/02280.jpg
#   inflating: data/images/01940.jpg
#   inflating: data/images/02096.jpg
#   inflating: data/images/01919.jpg
#   inflating: data/images/02451.jpg
#   inflating: data/images/02054.jpg
#   inflating: data/images/01006.jpg
#   inflating: data/images/02508.jpg
#   inflating: data/images/02622.jpg
#   inflating: data/images/02235.jpg
#   inflating: data/images/01267.jpg
#   inflating: data/images/02655.jpg
#   inflating: data/images/01472.jpg
#   inflating: data/images/02538.jpg
#   inflating: data/images/02363.jpg
#   inflating: data/images/02620.jpg
#   inflating: data/images/02575.jpg
#   inflating: data/images/01414.jpg
#   inflating: data/images/02060.jpg
#   inflating: data/images/02147.jpg
#   inflating: data/images/01257.jpg
#   inflating: data/images/02019.jpg
#   inflating: data/images/02411.jpg
#   inflating: data/images/01354.jpg
#   inflating: data/images/02124.jpg
#   inflating: data/images/00188.jpg
#   inflating: data/images/02628.jpg
#   inflating: data/images/02437.jpg
#   inflating: data/images/02276.jpg
#   inflating: data/images/02108.jpg
#   inflating: data/images/01334.jpg
#   inflating: data/images/02626.jpg
#   inflating: data/images/02423.jpg
#   inflating: data/images/02332.jpg
#   inflating: data/images/01896.jpg
#   inflating: data/images/01548.jpg
#   inflating: data/images/01275.jpg
#   inflating: data/images/02653.jpg
#   inflating: data/images/02131.jpg
#   inflating: data/images/02172.jpg
#   inflating: data/images/02580.jpg
#   inflating: data/images/01790.jpg
#   inflating: data/images/00528.jpg
#   inflating: data/images/01119.jpg
#   inflating: data/images/02578.jpg
#   inflating: data/images/02301.jpg
#   inflating: data/images/02128.jpg
#   inflating: data/images/02081.jpg
#   inflating: data/images/01281.jpg
#   inflating: data/images/01486.jpg
#   inflating: data/images/02615.jpg
#   inflating: data/images/01184.jpg
#   inflating: data/images/02592.jpg
#   inflating: data/images/01786.jpg
#   inflating: data/images/02568.jpg
#   inflating: data/images/01853.jpg
#   inflating: data/images/02677.jpg
#   inflating: data/images/01021.jpg
#   inflating: data/images/01960.jpg
#   inflating: data/images/00716.jpg
#   inflating: data/images/01497.jpg
#   inflating: data/images/02565.jpg
#   inflating: data/images/01118.jpg
#   inflating: data/images/02587.jpg
#   inflating: data/images/02362.jpg
#   inflating: data/images/02047.jpg
#   inflating: data/images/01891.jpg
#   inflating: data/images/01736.jpg
#   inflating: data/images/02652.jpg
#   inflating: data/images/01624.jpg
#   inflating: data/images/02456.jpg
#   inflating: data/images/00408.jpg
#   inflating: data/images/01762.jpg
#   inflating: data/images/01262.jpg
#   inflating: data/images/02682.jpg
#   inflating: data/images/02570.jpg
#   inflating: data/images/02658.jpg
#   inflating: data/images/02046.jpg
#   inflating: data/images/01848.jpg
#   inflating: data/images/01364.jpg
#   inflating: data/images/01782.jpg
#   inflating: data/images/02109.jpg
#   inflating: data/images/02271.jpg
#   inflating: data/images/01816.jpg
#   inflating: data/images/01990.jpg
#   inflating: data/images/01831.jpg
#   inflating: data/images/02296.jpg
#   inflating: data/images/02087.jpg
#   inflating: data/images/02389.jpg
#   inflating: data/images/00173.jpg
#   inflating: data/images/00909.jpg
#   inflating: data/images/02511.jpg
#   inflating: data/images/01949.jpg
#   inflating: data/images/02155.jpg
#   inflating: data/images/02378.jpg
#   inflating: data/images/02520.jpg
#   inflating: data/images/01785.jpg
#   inflating: data/images/02517.jpg
#   inflating: data/images/02424.jpg
#   inflating: data/images/02231.jpg
#   inflating: data/images/00213.jpg
#   inflating: data/images/01880.jpg
#   inflating: data/images/02433.jpg
#   inflating: data/images/02582.jpg
#   inflating: data/images/01245.jpg
#   inflating: data/images/02516.jpg
#   inflating: data/images/00951.jpg
#   inflating: data/images/02396.jpg
#   inflating: data/images/01886.jpg
#   inflating: data/images/01357.jpg
#   inflating: data/images/02123.jpg
#   inflating: data/images/01920.jpg
#   inflating: data/images/02670.jpg
#   inflating: data/images/00368.jpg
#   inflating: data/images/02640.jpg
#   inflating: data/images/02126.jpg
#   inflating: data/images/02669.jpg
#   inflating: data/images/02547.jpg
#   inflating: data/images/02209.jpg
#   inflating: data/images/00438.jpg
#   inflating: data/images/02444.jpg
#   inflating: data/images/01608.jpg
#   inflating: data/images/02239.jpg
#   inflating: data/images/00908.jpg
#   inflating: data/images/01744.jpg
#   inflating: data/images/00867.jpg
#   inflating: data/images/01351.jpg
#   inflating: data/images/00961.jpg
#   inflating: data/images/02221.jpg
#   inflating: data/images/02021.jpg
#   inflating: data/images/01964.jpg
#   inflating: data/images/02500.jpg
#   inflating: data/images/02556.jpg
#   inflating: data/images/00494.jpg
#   inflating: data/images/02311.jpg
#   inflating: data/images/02374.jpg
#   inflating: data/images/02381.jpg
#   inflating: data/images/02482.jpg
#   inflating: data/images/00591.jpg
#   inflating: data/images/01998.jpg
#   inflating: data/images/01838.jpg
#   inflating: data/images/01600.jpg
#   inflating: data/images/01730.jpg
#   inflating: data/images/01977.jpg
#   inflating: data/images/02264.jpg
#   inflating: data/images/02452.jpg
#   inflating: data/images/02651.jpg
#   inflating: data/images/02514.jpg
#   inflating: data/images/02040.jpg
#   inflating: data/images/02597.jpg
#   inflating: data/images/01173.jpg
#   inflating: data/images/02666.jpg
#   inflating: data/images/00259.jpg
#   inflating: data/images/02410.jpg
#   inflating: data/images/01963.jpg
#   inflating: data/images/02028.jpg
#   inflating: data/images/02347.jpg
#   inflating: data/images/02624.jpg
#   inflating: data/images/02142.jpg
#   inflating: data/images/01715.jpg
#   inflating: data/images/01360.jpg
#   inflating: data/images/01544.jpg
#   inflating: data/images/01528.jpg
#   inflating: data/images/02686.jpg
#   inflating: data/images/01922.jpg
#   inflating: data/images/02503.jpg
#   inflating: data/images/02135.jpg
#   inflating: data/images/01529.jpg
#   inflating: data/images/02487.jpg
#   inflating: data/images/02671.jpg
#   inflating: data/images/00047.jpg
#   inflating: data/images/02621.jpg
#   inflating: data/images/01614.jpg
#   inflating: data/images/00235.jpg
#   inflating: data/images/00863.jpg
#   inflating: data/images/02644.jpg
#   inflating: data/images/02418.jpg
#   inflating: data/images/02202.jpg
#   inflating: data/images/02214.jpg
#   inflating: data/images/01923.jpg
#   inflating: data/images/02690.jpg
#   inflating: data/images/02352.jpg
#   inflating: data/images/02179.jpg
#   inflating: data/images/02176.jpg
#   inflating: data/images/00806.jpg
#   inflating: data/images/01259.jpg
#   inflating: data/images/02499.jpg
#   inflating: data/images/01327.jpg
#   inflating: data/images/01971.jpg
#   inflating: data/images/02330.jpg
#   inflating: data/images/02334.jpg
#   inflating: data/images/02353.jpg
#   inflating: data/images/02627.jpg
#   inflating: data/images/01136.jpg
#   inflating: data/images/02004.jpg
#   inflating: data/images/02237.jpg
#   inflating: data/images/02283.jpg
#   inflating: data/images/02681.jpg
#   inflating: data/images/01504.jpg
#   inflating: data/images/01890.jpg
#   inflating: data/images/02595.jpg
#   inflating: data/images/01612.jpg
#   inflating: data/images/01866.jpg
#   inflating: data/images/02544.jpg
#   inflating: data/images/01026.jpg
#   inflating: data/images/02297.jpg
#   inflating: data/images/01975.jpg
#   inflating: data/images/00162.jpg
#   inflating: data/images/01205.jpg
#   inflating: data/images/02144.jpg
#   inflating: data/images/02244.jpg
#   inflating: data/images/02420.jpg
#   inflating: data/images/02319.jpg
#   inflating: data/images/01586.jpg
#   inflating: data/images/01908.jpg
#   inflating: data/images/01096.jpg
#   inflating: data/images/02166.jpg
#   inflating: data/images/01631.jpg
#   inflating: data/images/02206.jpg
#   inflating: data/images/00804.jpg
#   inflating: data/images/01828.jpg
#   inflating: data/images/00606.jpg
#   inflating: data/images/01775.jpg
#   inflating: data/images/02457.jpg
#   inflating: data/images/02479.jpg
#   inflating: data/images/02623.jpg
#   inflating: data/images/02139.jpg
#   inflating: data/images/01348.jpg
#   inflating: data/images/01892.jpg
#   inflating: data/images/02185.jpg
#   inflating: data/images/02037.jpg
#   inflating: data/images/02243.jpg
#   inflating: data/images/01425.jpg
#   inflating: data/images/01938.jpg
#   inflating: data/images/01359.jpg
#   inflating: data/images/01825.jpg
#   inflating: data/images/02515.jpg
#   inflating: data/images/01773.jpg
#   inflating: data/images/02219.jpg
#   inflating: data/images/02307.jpg
#   inflating: data/images/00617.jpg
#   inflating: data/images/02552.jpg
#   inflating: data/images/02639.jpg
#   inflating: data/images/02667.jpg
#   inflating: data/images/01875.jpg
#   inflating: data/images/02441.jpg
#   inflating: data/images/01716.jpg
#   inflating: data/images/02539.jpg
#   inflating: data/images/02608.jpg
#   inflating: data/images/02542.jpg
#   inflating: data/images/01917.jpg
#   inflating: data/images/01219.jpg
#   inflating: data/images/01814.jpg
#   inflating: data/images/01856.jpg
#   inflating: data/images/02039.jpg
#   inflating: data/images/01223.jpg
#   inflating: data/images/01632.jpg
#   inflating: data/images/02553.jpg
#   inflating: data/images/01855.jpg
#   inflating: data/images/01147.jpg
#   inflating: data/images/01407.jpg
#   inflating: data/images/00715.jpg
#   inflating: data/images/00100.jpg
#   inflating: data/images/02535.jpg
#   inflating: data/images/01167.jpg
#   inflating: data/images/02006.jpg
#   inflating: data/images/01231.jpg
#   inflating: data/images/02548.jpg
#   inflating: data/images/02103.jpg
#   inflating: data/images/02316.jpg
#   inflating: data/images/02341.jpg
#   inflating: data/images/02497.jpg
#   inflating: data/images/02590.jpg
#   inflating: data/images/01266.jpg
#   inflating: data/images/01546.jpg
#   inflating: data/images/02246.jpg
#   inflating: data/images/00449.jpg
#   inflating: data/images/01759.jpg
#   inflating: data/images/01720.jpg
#   inflating: data/images/01372.jpg
#   inflating: data/images/01457.jpg
#   inflating: data/images/00522.jpg
#   inflating: data/images/01409.jpg
#   inflating: data/images/01239.jpg
#   inflating: data/images/00060.jpg
#   inflating: data/images/02190.jpg
#   inflating: data/images/01870.jpg
#   inflating: data/images/01082.jpg
#   inflating: data/images/02175.jpg
#   inflating: data/images/01175.jpg
#   inflating: data/images/02589.jpg
#   inflating: data/images/01488.jpg
#   inflating: data/images/01779.jpg
#   inflating: data/images/02035.jpg
#   inflating: data/images/01610.jpg
#   inflating: data/images/02089.jpg
#   inflating: data/images/02581.jpg
#   inflating: data/images/01942.jpg
#   inflating: data/images/02234.jpg
#   inflating: data/images/02371.jpg
#   inflating: data/images/02226.jpg
#   inflating: data/images/02068.jpg
#   inflating: data/images/02694.jpg
#   inflating: data/images/02368.jpg
#   inflating: data/images/02562.jpg
#   inflating: data/images/02529.jpg
#   inflating: data/images/02116.jpg
#   inflating: data/images/00468.jpg
#   inflating: data/images/01615.jpg
#   inflating: data/images/01201.jpg
#   inflating: data/images/01900.jpg
#   inflating: data/images/02472.jpg
#   inflating: data/images/02584.jpg
#   inflating: data/images/02278.jpg
#   inflating: data/images/01333.jpg
#   inflating: data/images/02372.jpg
#   inflating: data/images/02011.jpg
#   inflating: data/images/02596.jpg
#   inflating: data/images/02646.jpg
#   inflating: data/images/01045.jpg
#   inflating: data/images/02546.jpg
#   inflating: data/images/02064.jpg
#   inflating: data/images/01918.jpg
#   inflating: data/images/02333.jpg
#   inflating: data/images/00940.jpg
#   inflating: data/images/01708.jpg
#   inflating: data/images/01995.jpg
#   inflating: data/images/00514.jpg
#   inflating: data/images/02174.jpg
#   inflating: data/images/02001.jpg
#   inflating: data/images/02305.jpg
#   inflating: data/images/01448.jpg
#   inflating: data/images/01944.jpg
#   inflating: data/images/01818.jpg
#   inflating: data/images/02465.jpg
#   inflating: data/images/02466.jpg
#   inflating: data/images/01408.jpg
#   inflating: data/images/01210.jpg
#   inflating: data/images/01445.jpg
#   inflating: data/images/02416.jpg
#   inflating: data/images/01972.jpg
#   inflating: data/images/00718.jpg
#   inflating: data/images/01363.jpg
#   inflating: data/images/02473.jpg
#   inflating: data/images/02384.jpg
#   inflating: data/images/01400.jpg
#   inflating: data/images/01809.jpg
#   inflating: data/images/01412.jpg
#   inflating: data/images/01131.jpg
#   inflating: data/images/01947.jpg
#   inflating: data/images/01187.jpg
#   inflating: data/images/02327.jpg
#   inflating: data/images/02657.jpg
#   inflating: data/images/01777.jpg
#   inflating: data/images/02158.jpg
#   inflating: data/images/02062.jpg
#   inflating: data/images/01113.jpg
#   inflating: data/images/02218.jpg
#   inflating: data/images/02454.jpg
#   inflating: data/images/02413.jpg
#   inflating: data/images/01017.jpg
#   inflating: data/images/01503.jpg
#   inflating: data/images/02094.jpg
#   inflating: data/images/01473.jpg
#   inflating: data/images/00155.jpg
#   inflating: data/images/01301.jpg
#   inflating: data/images/02377.jpg
#   inflating: data/images/02393.jpg
#   inflating: data/images/01991.jpg
#   inflating: data/images/02194.jpg
#   inflating: data/images/02551.jpg
#   inflating: data/images/01962.jpg
#   inflating: data/images/02675.jpg
#   inflating: data/images/02559.jpg
#   inflating: data/images/00049.jpg
#   inflating: data/images/02386.jpg
#   inflating: data/images/02745.jpg
#   inflating: data/images/02208.jpg
#   inflating: data/images/02315.jpg
#   inflating: data/images/00323.jpg
#   inflating: data/images/02809.jpg
#   inflating: data/images/02813.jpg
#   inflating: data/images/02830.jpg
#   inflating: data/images/02760.jpg
#   inflating: data/images/01023.jpg
#   inflating: data/images/01993.jpg
#   inflating: data/images/02260.jpg
#   inflating: data/images/01133.jpg
#   inflating: data/images/02875.jpg
#   inflating: data/images/02757.jpg
#   inflating: data/images/02821.jpg
#   inflating: data/images/01065.jpg
#   inflating: data/images/02746.jpg
#   inflating: data/images/01802.jpg
#   inflating: data/images/02679.jpg
#   inflating: data/images/00921.jpg
#   inflating: data/images/02775.jpg
#   inflating: data/images/02492.jpg
#   inflating: data/images/02712.jpg
#   inflating: data/images/02841.jpg
#   inflating: data/images/00541.jpg
#   inflating: data/images/02107.jpg
#   inflating: data/images/02537.jpg
#   inflating: data/images/02435.jpg
#   inflating: data/images/02400.jpg
#   inflating: data/images/01844.jpg
#   inflating: data/images/02355.jpg
#   inflating: data/images/01958.jpg
#   inflating: data/images/01084.jpg
#   inflating: data/images/01526.jpg
#   inflating: data/images/02261.jpg
#   inflating: data/images/00744.jpg
#   inflating: data/images/02090.jpg
#   inflating: data/images/02833.jpg
#   inflating: data/images/02854.jpg
#   inflating: data/images/01246.jpg
#   inflating: data/images/02104.jpg
#   inflating: data/images/02284.jpg
#   inflating: data/images/02616.jpg
#   inflating: data/images/01644.jpg
#   inflating: data/images/02762.jpg
#   inflating: data/images/02358.jpg
#   inflating: data/images/01734.jpg
#   inflating: data/images/01508.jpg
#   inflating: data/images/01471.jpg
#   inflating: data/images/02496.jpg
#   inflating: data/images/02530.jpg
#   inflating: data/images/01115.jpg
#   inflating: data/images/01476.jpg
#   inflating: data/images/02892.jpg
#   inflating: data/images/02057.jpg
#   inflating: data/images/01505.jpg
#   inflating: data/images/01858.jpg
#   inflating: data/images/02421.jpg
#   inflating: data/images/02692.jpg
#   inflating: data/images/01487.jpg
#   inflating: data/images/00967.jpg
#   inflating: data/images/02722.jpg
#   inflating: data/images/01769.jpg
#   inflating: data/images/01426.jpg
#   inflating: data/images/02003.jpg
#   inflating: data/images/01358.jpg
#   inflating: data/images/01830.jpg
#   inflating: data/images/02186.jpg
#   inflating: data/images/02891.jpg
#   inflating: data/images/01625.jpg
#   inflating: data/images/02873.jpg
#   inflating: data/images/02632.jpg
#   inflating: data/images/00249.jpg
#   inflating: data/images/02914.jpg
#   inflating: data/images/02342.jpg
#   inflating: data/images/01989.jpg
#   inflating: data/images/01898.jpg
#   inflating: data/images/02790.jpg
#   inflating: data/images/01091.jpg
#   inflating: data/images/02534.jpg
#   inflating: data/images/02749.jpg
#   inflating: data/images/02281.jpg
#   inflating: data/images/02819.jpg
#   inflating: data/images/02741.jpg
#   inflating: data/images/01000.jpg
#   inflating: data/images/02660.jpg
#   inflating: data/images/02591.jpg
#   inflating: data/images/00735.jpg
#   inflating: data/images/01467.jpg
#   inflating: data/images/01821.jpg
#   inflating: data/images/01484.jpg
#   inflating: data/images/02540.jpg
#   inflating: data/images/01933.jpg
#   inflating: data/images/02764.jpg
#   inflating: data/images/01545.jpg
#   inflating: data/images/01209.jpg
#   inflating: data/images/02802.jpg
#   inflating: data/images/00877.jpg
#   inflating: data/images/02610.jpg
#   inflating: data/images/02683.jpg
#   inflating: data/images/02708.jpg
#   inflating: data/images/02864.jpg
#   inflating: data/images/02105.jpg
#   inflating: data/images/02346.jpg
#   inflating: data/images/02180.jpg
#   inflating: data/images/02478.jpg
#   inflating: data/images/02566.jpg
#   inflating: data/images/01854.jpg
#   inflating: data/images/02489.jpg
#   inflating: data/images/01395.jpg
#   inflating: data/images/01980.jpg
#   inflating: data/images/01421.jpg
#   inflating: data/images/02954.jpg
#   inflating: data/images/03008.jpg
#   inflating: data/images/02693.jpg
#   inflating: data/images/00405.jpg
#   inflating: data/images/02846.jpg
#   inflating: data/images/02691.jpg
#   inflating: data/images/03003.jpg
#   inflating: data/images/02911.jpg
#   inflating: data/images/02697.jpg
#   inflating: data/images/03075.jpg
#   inflating: data/images/00465.jpg
#   inflating: data/images/01490.jpg
#   inflating: data/images/01712.jpg
#   inflating: data/images/02963.jpg
#   inflating: data/images/03069.jpg
#   inflating: data/images/03004.jpg
#   inflating: data/images/02803.jpg
#   inflating: data/images/02714.jpg
#   inflating: data/images/02838.jpg
#   inflating: data/images/02756.jpg
#   inflating: data/images/02956.jpg
#   inflating: data/images/01413.jpg
#   inflating: data/images/02403.jpg
#   inflating: data/images/01924.jpg
#   inflating: data/images/02738.jpg
#   inflating: data/images/03049.jpg
#   inflating: data/images/01812.jpg
#   inflating: data/images/03074.jpg
#   inflating: data/images/00297.jpg
#   inflating: data/images/01137.jpg
#   inflating: data/images/02323.jpg
#   inflating: data/images/02117.jpg
#   inflating: data/images/02979.jpg
#   inflating: data/images/03091.jpg
#   inflating: data/images/03107.jpg
#   inflating: data/images/00375.jpg
#   inflating: data/images/02835.jpg
#   inflating: data/images/02700.jpg
#   inflating: data/images/01120.jpg
#   inflating: data/images/01970.jpg
#   inflating: data/images/02823.jpg
#   inflating: data/images/01288.jpg
#   inflating: data/images/02795.jpg
#   inflating: data/images/03141.jpg
#   inflating: data/images/02910.jpg
#   inflating: data/images/03080.jpg
#   inflating: data/images/01884.jpg
#   inflating: data/images/02863.jpg
#   inflating: data/images/02558.jpg
#   inflating: data/images/02913.jpg
#   inflating: data/images/02828.jpg
#   inflating: data/images/02343.jpg
#   inflating: data/images/01025.jpg
#   inflating: data/images/02969.jpg
#   inflating: data/images/02585.jpg
#   inflating: data/images/03018.jpg
#   inflating: data/images/02831.jpg
#   inflating: data/images/02967.jpg
#   inflating: data/images/02782.jpg
#   inflating: data/images/00492.jpg
#   inflating: data/images/01620.jpg
#   inflating: data/images/02557.jpg
#   inflating: data/images/02786.jpg
#   inflating: data/images/03129.jpg
#   inflating: data/images/02944.jpg
#   inflating: data/images/02412.jpg
#   inflating: data/images/02361.jpg
#   inflating: data/images/02650.jpg
#   inflating: data/images/02872.jpg
#   inflating: data/images/02676.jpg
#   inflating: data/images/02422.jpg
#   inflating: data/images/03042.jpg
#   inflating: data/images/02858.jpg
#   inflating: data/images/03053.jpg
#   inflating: data/images/02865.jpg
#   inflating: data/images/02792.jpg
#   inflating: data/images/02141.jpg
#   inflating: data/images/01381.jpg
#   inflating: data/images/01852.jpg
#   inflating: data/images/02727.jpg
#   inflating: data/images/01749.jpg
#   inflating: data/images/02523.jpg
#   inflating: data/images/02799.jpg
#   inflating: data/images/01182.jpg
#   inflating: data/images/01713.jpg
#   inflating: data/images/02447.jpg
#   inflating: data/images/02825.jpg
#   inflating: data/images/02611.jpg
#   inflating: data/images/02600.jpg
#   inflating: data/images/01833.jpg
#   inflating: data/images/02197.jpg
#   inflating: data/images/01248.jpg
#   inflating: data/images/03096.jpg
#   inflating: data/images/02696.jpg
#   inflating: data/images/03294.jpg
#   inflating: data/images/03152.jpg
#   inflating: data/images/02849.jpg
#   inflating: data/images/02780.jpg
#   inflating: data/images/02796.jpg
#   inflating: data/images/03269.jpg
#   inflating: data/images/02440.jpg
#   inflating: data/images/02935.jpg
#   inflating: data/images/02966.jpg
#   inflating: data/images/03211.jpg
#   inflating: data/images/03118.jpg
#   inflating: data/images/03083.jpg
#   inflating: data/images/02603.jpg
#   inflating: data/images/03332.jpg
#   inflating: data/images/02329.jpg
#   inflating: data/images/03058.jpg
#   inflating: data/images/02820.jpg
#   inflating: data/images/00104.jpg
#   inflating: data/images/01897.jpg
#   inflating: data/images/03289.jpg
#   inflating: data/images/03343.jpg
#   inflating: data/images/03022.jpg
#   inflating: data/images/02365.jpg
#   inflating: data/images/02899.jpg
#   inflating: data/images/02005.jpg
#   inflating: data/images/02606.jpg
#   inflating: data/images/01520.jpg
#   inflating: data/images/03043.jpg
#   inflating: data/images/03204.jpg
#   inflating: data/images/02810.jpg
#   inflating: data/images/02059.jpg
#   inflating: data/images/02067.jpg
#   inflating: data/images/02295.jpg
#   inflating: data/images/03307.jpg
#   inflating: data/images/03135.jpg
#   inflating: data/images/03137.jpg
#   inflating: data/images/02070.jpg
#   inflating: data/images/00906.jpg
#   inflating: data/images/02761.jpg
#   inflating: data/images/01705.jpg
#   inflating: data/images/03175.jpg
#   inflating: data/images/02787.jpg
#   inflating: data/images/01950.jpg
#   inflating: data/images/01512.jpg
#   inflating: data/images/03243.jpg
#   inflating: data/images/03177.jpg
#   inflating: data/images/00469.jpg
#   inflating: data/images/02735.jpg
#   inflating: data/images/02391.jpg
#   inflating: data/images/02299.jpg
#   inflating: data/images/00969.jpg
#   inflating: data/images/03124.jpg
#   inflating: data/images/03108.jpg
#   inflating: data/images/02829.jpg
#   inflating: data/images/02996.jpg
#   inflating: data/images/02338.jpg
#   inflating: data/images/01402.jpg
#   inflating: data/images/01237.jpg
#   inflating: data/images/03046.jpg
#   inflating: data/images/03028.jpg
#   inflating: data/images/00491.jpg
#   inflating: data/images/02300.jpg
#   inflating: data/images/03142.jpg
#   inflating: data/images/02812.jpg
#   inflating: data/images/02773.jpg
#   inflating: data/images/03311.jpg
#   inflating: data/images/02160.jpg
#   inflating: data/images/02701.jpg
#   inflating: data/images/02130.jpg
#   inflating: data/images/01243.jpg
#   inflating: data/images/02939.jpg
#   inflating: data/images/03266.jpg
#   inflating: data/images/03281.jpg
#   inflating: data/images/02917.jpg
#   inflating: data/images/00542.jpg
#   inflating: data/images/02699.jpg
#   inflating: data/images/03252.jpg
#   inflating: data/images/02672.jpg
#   inflating: data/images/01234.jpg
#   inflating: data/images/02715.jpg
#   inflating: data/images/02885.jpg
#   inflating: data/images/01727.jpg
#   inflating: data/images/00026.jpg
#   inflating: data/images/03322.jpg
#   inflating: data/images/01842.jpg
#   inflating: data/images/03282.jpg
#   inflating: data/images/03078.jpg
#   inflating: data/images/02350.jpg
#   inflating: data/images/02797.jpg
#   inflating: data/images/03072.jpg
#   inflating: data/images/01122.jpg
#   inflating: data/images/02373.jpg
#   inflating: data/images/03247.jpg
#   inflating: data/images/02133.jpg
#   inflating: data/images/02152.jpg
#   inflating: data/images/03138.jpg
#   inflating: data/images/02868.jpg
#   inflating: data/images/02924.jpg
#   inflating: data/images/03161.jpg
#   inflating: data/images/00326.jpg
#   inflating: data/images/02862.jpg
#   inflating: data/images/02718.jpg
#   inflating: data/images/03094.jpg
#   inflating: data/images/03167.jpg
#   inflating: data/images/02481.jpg
#   inflating: data/images/01511.jpg
#   inflating: data/images/02033.jpg
#   inflating: data/images/01216.jpg
#   inflating: data/images/02241.jpg
#   inflating: data/images/01788.jpg
#   inflating: data/images/03312.jpg
#   inflating: data/images/03054.jpg
#   inflating: data/images/01729.jpg
#   inflating: data/images/03372.jpg
#   inflating: data/images/03202.jpg
#   inflating: data/images/03171.jpg
#   inflating: data/images/01617.jpg
#   inflating: data/images/02063.jpg
#   inflating: data/images/02275.jpg
#   inflating: data/images/03015.jpg
#   inflating: data/images/01570.jpg
#   inflating: data/images/02848.jpg
#   inflating: data/images/03249.jpg
#   inflating: data/images/03250.jpg
#   inflating: data/images/02983.jpg
#   inflating: data/images/03368.jpg
#   inflating: data/images/01148.jpg
#   inflating: data/images/03286.jpg
#   inflating: data/images/01906.jpg
#   inflating: data/images/01533.jpg
#   inflating: data/images/02895.jpg
#   inflating: data/images/03302.jpg
#   inflating: data/images/03176.jpg
#   inflating: data/images/01756.jpg
#   inflating: data/images/03351.jpg
#   inflating: data/images/02680.jpg
#   inflating: data/images/03133.jpg
#   inflating: data/images/02505.jpg
#   inflating: data/images/01706.jpg
#   inflating: data/images/01843.jpg
#   inflating: data/images/03191.jpg
#   inflating: data/images/03064.jpg
#   inflating: data/images/03296.jpg
#   inflating: data/images/02619.jpg
#   inflating: data/images/00625.jpg
#   inflating: data/images/00860.jpg
#   inflating: data/images/00057.jpg
#   inflating: data/images/02884.jpg
#   inflating: data/images/03031.jpg
#   inflating: data/images/03039.jpg
#   inflating: data/images/03082.jpg
#   inflating: data/images/02345.jpg
#   inflating: data/images/03038.jpg
#   inflating: data/images/02770.jpg
#   inflating: data/images/03217.jpg
#   inflating: data/images/00433.jpg
#   inflating: data/images/03201.jpg
#   inflating: data/images/02906.jpg
#   inflating: data/images/01155.jpg
#   inflating: data/images/03165.jpg
#   inflating: data/images/02886.jpg
#   inflating: data/images/03066.jpg
#   inflating: data/images/03278.jpg
#   inflating: data/images/00608.jpg
#   inflating: data/images/03261.jpg
#   inflating: data/images/02798.jpg
#   inflating: data/images/01714.jpg
#   inflating: data/images/03253.jpg
#   inflating: data/images/02962.jpg
#   inflating: data/images/01225.jpg
#   inflating: data/images/02981.jpg
#   inflating: data/images/02588.jpg
#   inflating: data/images/02182.jpg
#   inflating: data/images/00958.jpg
#   inflating: data/images/02857.jpg
#   inflating: data/images/02443.jpg
#   inflating: data/images/03179.jpg
#   inflating: data/images/03268.jpg
#   inflating: data/images/03308.jpg
#   inflating: data/images/03270.jpg
#   inflating: data/images/01475.jpg
#   inflating: data/images/03150.jpg
#   inflating: data/images/02869.jpg
#   inflating: data/images/01748.jpg
#   inflating: data/images/03097.jpg
#   inflating: data/images/01862.jpg
#   inflating: data/images/02882.jpg
#   inflating: data/images/02247.jpg
#   inflating: data/images/03264.jpg
#   inflating: data/images/00233.jpg
#   inflating: data/images/02942.jpg
#   inflating: data/images/00499.jpg
#   inflating: data/images/01125.jpg
#   inflating: data/images/02986.jpg
#   inflating: data/images/01765.jpg
#   inflating: data/images/02771.jpg
#   inflating: data/images/03157.jpg
#   inflating: data/images/00112.jpg
#   inflating: data/images/02531.jpg
#   inflating: data/images/01390.jpg
#   inflating: data/images/02458.jpg
#   inflating: data/images/02317.jpg
#   inflating: data/images/01455.jpg
#   inflating: data/images/01930.jpg
#   inflating: data/images/02991.jpg
#   inflating: data/images/02594.jpg
#   inflating: data/images/02614.jpg
#   inflating: data/images/02927.jpg
#   inflating: data/images/02227.jpg
#   inflating: data/images/03251.jpg
#   inflating: data/images/01789.jpg
#   inflating: data/images/02101.jpg
#   inflating: data/images/01894.jpg
#   inflating: data/images/02880.jpg
#   inflating: data/images/02938.jpg
#   inflating: data/images/02763.jpg
#   inflating: data/images/03301.jpg
#   inflating: data/images/03106.jpg
#   inflating: data/images/03258.jpg
#   inflating: data/images/03109.jpg
#   inflating: data/images/03321.jpg
#   inflating: data/images/01482.jpg
#   inflating: data/images/03002.jpg
#   inflating: data/images/01541.jpg
#   inflating: data/images/02674.jpg
#   inflating: data/images/01172.jpg
#   inflating: data/images/03237.jpg
#   inflating: data/images/02765.jpg
#   inflating: data/images/03010.jpg
#   inflating: data/images/03262.jpg
#   inflating: data/images/03115.jpg
#   inflating: data/images/01332.jpg
#   inflating: data/images/03310.jpg
#   inflating: data/images/02079.jpg
#   inflating: data/images/02959.jpg
#   inflating: data/images/03076.jpg
#   inflating: data/images/02750.jpg
#   inflating: data/images/01829.jpg
#   inflating: data/images/01276.jpg
#   inflating: data/images/03185.jpg
#   inflating: data/images/02811.jpg
#   inflating: data/images/01572.jpg
#   inflating: data/images/03020.jpg
#   inflating: data/images/02601.jpg
#   inflating: data/images/03300.jpg
#   inflating: data/images/03197.jpg
#   inflating: data/images/03324.jpg
#   inflating: data/images/03210.jpg
#   inflating: data/images/02968.jpg
#   inflating: data/images/00142.jpg
#   inflating: data/images/03101.jpg
#   inflating: data/images/02997.jpg
#   inflating: data/images/01793.jpg
#   inflating: data/images/01077.jpg
#   inflating: data/images/01104.jpg
#   inflating: data/images/03030.jpg
#   inflating: data/images/02560.jpg
#   inflating: data/images/03333.jpg
#   inflating: data/images/03164.jpg
#   inflating: data/images/03073.jpg
#   inflating: data/images/01796.jpg
#   inflating: data/images/03037.jpg
#   inflating: data/images/02138.jpg
#   inflating: data/images/03316.jpg
#   inflating: data/images/03061.jpg
#   inflating: data/images/03104.jpg
#   inflating: data/images/02970.jpg
#   inflating: data/images/03160.jpg
#   inflating: data/images/03309.jpg
#   inflating: data/images/01203.jpg
#   inflating: data/images/02853.jpg
#   inflating: data/images/00382.jpg
#   inflating: data/images/02901.jpg
#   inflating: data/images/02326.jpg
#   inflating: data/images/03009.jpg
#   inflating: data/images/02755.jpg
#   inflating: data/images/03288.jpg
#   inflating: data/images/02084.jpg
#   inflating: data/images/02263.jpg
#   inflating: data/images/01012.jpg
#   inflating: data/images/00912.jpg
#   inflating: data/images/02905.jpg
#   inflating: data/images/02149.jpg
#   inflating: data/images/02784.jpg
#   inflating: data/images/02321.jpg
#   inflating: data/images/03299.jpg
#   inflating: data/images/01817.jpg
#   inflating: data/images/02474.jpg
#   inflating: data/images/03032.jpg
#   inflating: data/images/02876.jpg
#   inflating: data/images/01240.jpg
#   inflating: data/images/02272.jpg
#   inflating: data/images/03330.jpg
#   inflating: data/images/02036.jpg
#   inflating: data/images/03203.jpg
#   inflating: data/images/02753.jpg
#   inflating: data/images/01556.jpg
#   inflating: data/images/01255.jpg
#   inflating: data/images/02199.jpg
#   inflating: data/images/03055.jpg
#   inflating: data/images/01780.jpg
#   inflating: data/images/02678.jpg
#   inflating: data/images/02634.jpg
#   inflating: data/images/02495.jpg
#   inflating: data/images/01753.jpg
#   inflating: data/images/02121.jpg
#   inflating: data/images/03198.jpg
#   inflating: data/images/03158.jpg
#   inflating: data/images/02916.jpg
#   inflating: data/images/03155.jpg
#   inflating: data/images/01146.jpg
#   inflating: data/images/03047.jpg
#   inflating: data/images/02154.jpg
#   inflating: data/images/02870.jpg
#   inflating: data/images/01787.jpg
#   inflating: data/images/00103.jpg
#   inflating: data/images/03189.jpg
#   inflating: data/images/02322.jpg
#   inflating: data/images/02852.jpg
#   inflating: data/images/02889.jpg
#   inflating: data/images/01994.jpg
#   inflating: data/images/02318.jpg
#   inflating: data/images/02717.jpg
#   inflating: data/images/01893.jpg
#   inflating: data/images/02598.jpg
#   inflating: data/images/00597.jpg
#   inflating: data/images/02663.jpg
#   inflating: data/images/02687.jpg
#   inflating: data/images/00327.jpg
#   inflating: data/images/00885.jpg
#   inflating: data/images/02877.jpg
#   inflating: data/images/01819.jpg
#   inflating: data/images/01369.jpg
#   inflating: data/images/02654.jpg
#   inflating: data/images/02336.jpg
#   inflating: data/images/01254.jpg
#   inflating: data/images/03259.jpg
#   inflating: data/images/01841.jpg
#   inflating: data/images/02840.jpg
#   inflating: data/images/02861.jpg
#   inflating: data/images/02053.jpg
#   inflating: data/images/02430.jpg
#   inflating: data/images/02737.jpg
#   inflating: data/images/03113.jpg
#   inflating: data/images/03291.jpg
#   inflating: data/images/03208.jpg
#   inflating: data/images/00218.jpg
#   inflating: data/images/03216.jpg
#   inflating: data/images/02242.jpg
#   inflating: data/images/02541.jpg
#   inflating: data/images/01397.jpg
#   inflating: data/images/02112.jpg
#   inflating: data/images/02604.jpg
#   inflating: data/images/03001.jpg
#   inflating: data/images/03088.jpg
#   inflating: data/images/00078.jpg
#   inflating: data/images/01800.jpg
#   inflating: data/images/03267.jpg
#   inflating: data/images/02791.jpg
#   inflating: data/images/01781.jpg
#   inflating: data/images/00997.jpg
#   inflating: data/images/02132.jpg
#   inflating: data/images/02881.jpg
#   inflating: data/images/01864.jpg
#   inflating: data/images/02850.jpg
#   inflating: data/images/00600.jpg
#   inflating: data/images/03323.jpg
#   inflating: data/images/02432.jpg
#   inflating: data/images/03388.jpg
#   inflating: data/images/03116.jpg
#   inflating: data/images/03575.jpg
#   inflating: data/images/01903.jpg
#   inflating: data/images/03497.jpg
#   inflating: data/images/03404.jpg
#   inflating: data/images/02617.jpg
#   inflating: data/images/02512.jpg
#   inflating: data/images/03417.jpg
#   inflating: data/images/01948.jpg
#   inflating: data/images/03100.jpg
#   inflating: data/images/03418.jpg
#   inflating: data/images/01702.jpg
#   inflating: data/images/02781.jpg
#   inflating: data/images/03406.jpg
#   inflating: data/images/02984.jpg
#   inflating: data/images/02724.jpg
#   inflating: data/images/00634.jpg
#   inflating: data/images/02903.jpg
#   inflating: data/images/02043.jpg
#   inflating: data/images/03518.jpg
#   inflating: data/images/00923.jpg
#   inflating: data/images/02900.jpg
#   inflating: data/images/03566.jpg
#   inflating: data/images/02513.jpg
#   inflating: data/images/01420.jpg
#   inflating: data/images/03421.jpg
#   inflating: data/images/03371.jpg
#   inflating: data/images/02493.jpg
#   inflating: data/images/01834.jpg
#   inflating: data/images/03207.jpg
#   inflating: data/images/01162.jpg
#   inflating: data/images/01951.jpg
#   inflating: data/images/03098.jpg
#   inflating: data/images/00241.jpg
#   inflating: data/images/00234.jpg
#   inflating: data/images/03048.jpg
#   inflating: data/images/03419.jpg
#   inflating: data/images/02988.jpg
#   inflating: data/images/03188.jpg
#   inflating: data/images/01751.jpg
#   inflating: data/images/01224.jpg
#   inflating: data/images/03624.jpg
#   inflating: data/images/02814.jpg
#   inflating: data/images/02946.jpg
#   inflating: data/images/03260.jpg
#   inflating: data/images/02550.jpg
#   inflating: data/images/02071.jpg
#   inflating: data/images/02960.jpg
#   inflating: data/images/01810.jpg
#   inflating: data/images/02567.jpg
#   inflating: data/images/03277.jpg
#   inflating: data/images/02000.jpg
#   inflating: data/images/00944.jpg
# ...
#   inflating: data/images/06000.jpg
#   inflating: data/images/06461.jpg
#   inflating: data/images/05120.jpg
#   inflating: data/images/06887.jpg
#   inflating: data/images/05454.jpg
#   inflating: data/images/05514.jpg
#   inflating: data/images/06569.jpg
#   inflating: data/images/05022.jpg
#   inflating: data/images/06763.jpg
#   inflating: data/images/04886.jpg
#   inflating: data/images/05649.jpg
#   inflating: data/images/02287.jpg
#   inflating: data/images/03345.jpg
#   inflating: data/images/06234.jpg
#   inflating: data/images/04203.jpg
#   inflating: data/images/06546.jpg
#   inflating: data/images/06571.jpg
#   inflating: data/images/00393.jpg
#   inflating: data/images/03151.jpg
#   inflating: data/images/06556.jpg
#   inflating: data/images/06102.jpg
#   inflating: data/images/06805.jpg
#   inflating: data/images/05796.jpg
#   inflating: data/images/05312.jpg
#   inflating: data/images/06330.jpg
#   inflating: data/images/04809.jpg
#   inflating: data/images/04541.jpg
#   inflating: data/images/04833.jpg
#   inflating: data/images/06329.jpg
#   inflating: data/images/05753.jpg
#   inflating: data/images/03811.jpg
#   inflating: data/images/05906.jpg
#   inflating: data/images/04430.jpg
#   inflating: data/images/06700.jpg
#   inflating: data/images/03738.jpg
#   inflating: data/images/04536.jpg
#   inflating: data/images/05159.jpg
#   inflating: data/images/04340.jpg
#   inflating: data/images/06387.jpg
#   inflating: data/images/06642.jpg
#   inflating: data/images/05445.jpg
#   inflating: data/images/06751.jpg
#   inflating: data/images/04638.jpg
#   inflating: data/images/06698.jpg
#   inflating: data/images/05760.jpg
#   inflating: data/images/06247.jpg
#   inflating: data/images/05642.jpg
#   inflating: data/images/06225.jpg
#   inflating: data/images/05599.jpg
#   inflating: data/images/06870.jpg
#   inflating: data/images/06189.jpg
#   inflating: data/images/05378.jpg
#   inflating: data/images/06808.jpg
#   inflating: data/images/06160.jpg
#   inflating: data/images/06393.jpg
#   inflating: data/images/06667.jpg
#   inflating: data/images/00583.jpg
#   inflating: data/images/02605.jpg
#   inflating: data/images/04797.jpg
#   inflating: data/images/06732.jpg
#   inflating: data/images/05038.jpg
#   inflating: data/images/06222.jpg
#   inflating: data/images/02504.jpg
#   inflating: data/images/06533.jpg
#   inflating: data/images/02522.jpg
#   inflating: data/images/06186.jpg
#   inflating: data/images/06844.jpg
#   inflating: data/images/06185.jpg
#   inflating: data/images/06146.jpg
#   inflating: data/images/05144.jpg
#   inflating: data/images/06754.jpg
#   inflating: data/images/04442.jpg
#   inflating: data/images/01997.jpg
#   inflating: data/images/05304.jpg
#   inflating: data/images/04579.jpg
#   inflating: data/images/06838.jpg
#   inflating: data/images/05308.jpg
#   inflating: data/images/04642.jpg
#   inflating: data/images/04404.jpg
#   inflating: data/images/03382.jpg
#   inflating: data/images/05911.jpg
#   inflating: data/images/02198.jpg
#   inflating: data/images/02419.jpg
#   inflating: data/images/05112.jpg
#   inflating: data/images/04180.jpg
#   inflating: data/images/02836.jpg
#   inflating: data/images/03527.jpg
#   inflating: data/images/03632.jpg
#   inflating: data/images/02509.jpg
#   inflating: data/images/04771.jpg
#   inflating: data/images/06749.jpg
#   inflating: data/images/05427.jpg
#   inflating: data/images/05979.jpg
#   inflating: data/images/04444.jpg
#   inflating: data/images/06867.jpg
#   inflating: data/images/05375.jpg
#   inflating: data/images/04136.jpg
#   inflating: data/images/06739.jpg
#   inflating: data/images/04416.jpg
#   inflating: data/images/04752.jpg
#   inflating: data/images/02665.jpg
#   inflating: data/images/01571.jpg
#   inflating: data/images/04163.jpg
#   inflating: data/images/06586.jpg
#   inflating: data/images/05526.jpg
#   inflating: data/images/06729.jpg
#   inflating: data/images/05591.jpg
#   inflating: data/images/04745.jpg
#   inflating: data/images/06825.jpg
#   inflating: data/images/06523.jpg
#   inflating: data/images/05503.jpg
#   inflating: data/images/02951.jpg
#   inflating: data/images/03739.jpg
#   inflating: data/images/02114.jpg
#   inflating: data/images/04129.jpg
#   inflating: data/images/06459.jpg
#   inflating: data/images/06203.jpg
#   inflating: data/images/01483.jpg
#   inflating: data/images/06388.jpg
#   inflating: data/images/04694.jpg
#   inflating: data/images/04618.jpg
#   inflating: data/images/02120.jpg
#   inflating: data/images/06358.jpg
#   inflating: data/images/00353.jpg
#   inflating: data/images/04822.jpg
#   inflating: data/images/03199.jpg
#   inflating: data/images/05850.jpg
#   inflating: data/images/01142.jpg
#   inflating: data/images/06474.jpg
#   inflating: data/images/03079.jpg
#   inflating: data/images/04021.jpg
#   inflating: data/images/05135.jpg
#   inflating: data/images/03370.jpg
#   inflating: data/images/04269.jpg
#   inflating: data/images/03528.jpg
#   inflating: data/images/05532.jpg
#   inflating: data/images/06695.jpg
#   inflating: data/images/01534.jpg
#   inflating: data/images/06319.jpg
#   inflating: data/images/05597.jpg
#   inflating: data/images/06027.jpg
#   inflating: data/images/06370.jpg
#   inflating: data/images/06538.jpg
#   inflating: data/images/06306.jpg
#   inflating: data/images/06204.jpg
#   inflating: data/images/05629.jpg
#   inflating: data/images/05989.jpg
#   inflating: data/images/04612.jpg
#   inflating: data/images/06756.jpg
#   inflating: data/images/02159.jpg
#   inflating: data/images/05754.jpg
#   inflating: data/images/05426.jpg
#   inflating: data/images/04845.jpg
#   inflating: data/images/03815.jpg
#   inflating: data/images/06195.jpg
#   inflating: data/images/06877.jpg
#   inflating: data/images/05745.jpg
#   inflating: data/images/06137.jpg
#   inflating: data/images/05073.jpg
#   inflating: data/images/02527.jpg
#   inflating: data/images/04953.jpg
#   inflating: data/images/01557.jpg
#   inflating: data/images/01861.jpg
#   inflating: data/images/05679.jpg
#   inflating: data/images/05871.jpg
#   inflating: data/images/06740.jpg
#   inflating: data/images/06551.jpg
#   inflating: data/images/03988.jpg
#   inflating: data/images/05915.jpg
#   inflating: data/images/06528.jpg
#   inflating: data/images/02965.jpg
#   inflating: data/images/06510.jpg
#   inflating: data/images/06625.jpg
#   inflating: data/images/04560.jpg
#   inflating: data/images/06355.jpg
#   inflating: data/images/06765.jpg
#   inflating: data/images/06711.jpg
#   inflating: data/images/05006.jpg
#   inflating: data/images/06774.jpg
#   inflating: data/images/04554.jpg
#   inflating: data/images/03119.jpg
#   inflating: data/images/02434.jpg
#   inflating: data/images/03693.jpg
#   inflating: data/images/05044.jpg
#   inflating: data/images/06681.jpg
#   inflating: data/images/02711.jpg
#   inflating: data/images/02392.jpg
#   inflating: data/images/05749.jpg
#   inflating: data/images/06174.jpg
#   inflating: data/images/04551.jpg
#   inflating: data/images/03896.jpg
#   inflating: data/images/03816.jpg
#   inflating: data/images/02878.jpg
#   inflating: data/images/04223.jpg
#   inflating: data/images/02402.jpg
#   inflating: data/images/04660.jpg
#   inflating: data/images/02887.jpg
#   inflating: data/images/05238.jpg
#   inflating: data/images/05724.jpg
#   inflating: data/images/06337.jpg
#   inflating: data/images/00748.jpg
#   inflating: data/images/06092.jpg
#   inflating: data/images/05522.jpg
#   inflating: data/images/06177.jpg
#   inflating: data/images/06802.jpg
#   inflating: data/images/06098.jpg
#   inflating: data/images/05808.jpg
#   inflating: data/images/02189.jpg
#   inflating: data/images/04572.jpg
#   inflating: data/images/01434.jpg
#   inflating: data/images/01344.jpg
#   inflating: data/images/03480.jpg
#   inflating: data/images/00592.jpg
#   inflating: data/images/01491.jpg
#   inflating: data/images/06147.jpg
#   inflating: data/images/02092.jpg
#   inflating: data/images/05841.jpg
#   inflating: data/images/06372.jpg
#   inflating: data/images/03408.jpg
#   inflating: data/images/04933.jpg
#   inflating: data/images/03500.jpg
#   inflating: data/images/03626.jpg
#   inflating: data/images/02303.jpg
#   inflating: data/images/01943.jpg
#   inflating: data/images/05882.jpg
#   inflating: data/images/01293.jpg
#   inflating: data/images/00416.jpg
#   inflating: data/images/03864.jpg
#   inflating: data/images/01733.jpg
#   inflating: data/images/05101.jpg
#   inflating: data/images/01637.jpg
#   inflating: data/images/04964.jpg
#   inflating: data/images/00746.jpg
#   inflating: data/images/03383.jpg
#   inflating: data/images/05622.jpg
#   inflating: data/images/05130.jpg
#   inflating: data/images/05600.jpg
#   inflating: data/images/05123.jpg
#   inflating: data/images/03475.jpg
#   inflating: data/images/03027.jpg
#   inflating: data/images/06673.jpg
#   inflating: data/images/05414.jpg
#   inflating: data/images/05462.jpg
#   inflating: data/images/05857.jpg
#   inflating: data/images/03610.jpg
#   inflating: data/images/02048.jpg
#   inflating: data/images/03163.jpg
#   inflating: data/images/02769.jpg
#   inflating: data/images/01616.jpg
#   inflating: data/images/04609.jpg
#   inflating: data/images/03328.jpg
#   inflating: data/images/05836.jpg
#   inflating: data/images/05616.jpg
#   inflating: data/images/05934.jpg
#   inflating: data/images/03013.jpg
#   inflating: data/images/04374.jpg
#   inflating: data/images/03263.jpg
#   inflating: data/images/00529.jpg
#   inflating: data/images/06226.jpg
#   inflating: data/images/03981.jpg
#   inflating: data/images/05422.jpg
#   inflating: data/images/04151.jpg
#   inflating: data/images/03349.jpg
#   inflating: data/images/04120.jpg
#   inflating: data/images/05406.jpg
#   inflating: data/images/01607.jpg
#   inflating: data/images/01367.jpg
#   inflating: data/images/05059.jpg
#   inflating: data/images/04625.jpg
#   inflating: data/images/05104.jpg
#   inflating: data/images/04493.jpg
#   inflating: data/images/01062.jpg
#   inflating: data/images/00504.jpg
#   inflating: data/images/05974.jpg
#   inflating: data/images/01029.jpg
#   inflating: data/images/00523.jpg
#   inflating: data/images/03284.jpg
#   inflating: data/images/02897.jpg
#   inflating: data/images/06038.jpg
#   inflating: data/images/04263.jpg
#   inflating: data/images/05982.jpg
#   inflating: data/images/02860.jpg
#   inflating: data/images/06726.jpg
#   inflating: data/images/05412.jpg
#   inflating: data/images/06158.jpg
#   inflating: data/images/06133.jpg
#   inflating: data/images/05389.jpg
#   inflating: data/images/03070.jpg
#   inflating: data/images/01204.jpg
#   inflating: data/images/02661.jpg
#   inflating: data/images/05980.jpg
#   inflating: data/images/04165.jpg
#   inflating: data/images/06359.jpg
#   inflating: data/images/01464.jpg
#   inflating: data/images/04504.jpg
#   inflating: data/images/01988.jpg
#   inflating: data/images/05450.jpg
#   inflating: data/images/05496.jpg
#   inflating: data/images/06221.jpg
#   inflating: data/images/04653.jpg
#   inflating: data/images/06714.jpg
#   inflating: data/images/06515.jpg
#   inflating: data/images/01268.jpg
#   inflating: data/images/00733.jpg
#   inflating: data/images/01999.jpg
#   inflating: data/images/05913.jpg
#   inflating: data/images/05334.jpg
#   inflating: data/images/00157.jpg
#   inflating: data/images/04872.jpg
#   inflating: data/images/05100.jpg
#   inflating: data/images/06139.jpg
#   inflating: data/images/03951.jpg
#   inflating: data/images/03153.jpg
#   inflating: data/images/01763.jpg
#   inflating: data/images/05229.jpg
#   inflating: data/images/05633.jpg
#   inflating: data/images/05950.jpg
#   inflating: data/images/01772.jpg
#   inflating: data/images/01366.jpg
#   inflating: data/images/03810.jpg
#   inflating: data/images/02912.jpg
#   inflating: data/images/01499.jpg
#   inflating: data/images/04921.jpg
#   inflating: data/images/02978.jpg
#   inflating: data/images/06718.jpg
#   inflating: data/images/01067.jpg
#   inflating: data/images/04214.jpg
#   inflating: data/images/05664.jpg
#   inflating: data/images/03735.jpg
#   inflating: data/images/00461.jpg
#   inflating: data/images/03536.jpg
#   inflating: data/images/04088.jpg
#   inflating: data/images/02041.jpg
#   inflating: data/images/02156.jpg
#   inflating: data/images/06238.jpg
#   inflating: data/images/02267.jpg
#   inflating: data/images/05855.jpg
#   inflating: data/images/04306.jpg
#   inflating: data/images/03730.jpg
#   inflating: data/images/03460.jpg
#   inflating: data/images/04104.jpg
#   inflating: data/images/01530.jpg
#   inflating: data/images/05181.jpg
#   inflating: data/images/04510.jpg
#   inflating: data/images/04992.jpg
#   inflating: data/images/05494.jpg
#   inflating: data/images/03877.jpg
#   inflating: data/images/00221.jpg
#   inflating: data/images/02312.jpg
#   inflating: data/images/05594.jpg
#   inflating: data/images/00890.jpg
#   inflating: data/images/01605.jpg
#   inflating: data/images/00827.jpg
#   inflating: data/images/05228.jpg
#   inflating: data/images/03699.jpg
#   inflating: data/images/05497.jpg
#   inflating: data/images/04367.jpg
#   inflating: data/images/02659.jpg
#   inflating: data/images/05946.jpg
#   inflating: data/images/01754.jpg
#   inflating: data/images/05992.jpg
#   inflating: data/images/02789.jpg
#   inflating: data/images/00530.jpg
#   inflating: data/images/05491.jpg
#   inflating: data/images/01952.jpg
#   inflating: data/images/02245.jpg
#   inflating: data/images/04117.jpg
#   inflating: data/images/01823.jpg
#   inflating: data/images/03112.jpg
#   inflating: data/images/00125.jpg
#   inflating: data/images/02609.jpg
#   inflating: data/images/00520.jpg
#   inflating: data/images/02015.jpg
#   inflating: data/images/03168.jpg
#   inflating: data/images/02442.jpg
#   inflating: data/images/00397.jpg
#   inflating: data/images/01212.jpg
#   inflating: data/images/01868.jpg
#   inflating: data/images/05619.jpg
#   inflating: data/images/00627.jpg
#   inflating: data/images/01978.jpg
#   inflating: data/images/01969.jpg
#   inflating: data/images/01912.jpg
#   inflating: data/images/02837.jpg
#   inflating: data/images/01087.jpg
#   inflating: data/images/03690.jpg
#   inflating: data/images/03380.jpg
#   inflating: data/images/04131.jpg
#   inflating: data/images/01750.jpg
#   inflating: data/images/00593.jpg
#   inflating: data/images/05243.jpg
#   inflating: data/images/01623.jpg
#   inflating: data/images/03244.jpg
#   inflating: data/images/00977.jpg
#   inflating: data/images/00169.jpg
#   inflating: data/images/02728.jpg
#   inflating: data/images/03393.jpg
#   inflating: data/images/01066.jpg
#   inflating: data/images/05174.jpg
#   inflating: data/images/02129.jpg
#   inflating: data/images/02752.jpg
#   inflating: data/images/00261.jpg
#   inflating: data/images/03970.jpg
#   inflating: data/images/02528.jpg
#   inflating: data/images/02491.jpg
#   inflating: data/images/03034.jpg
#   inflating: data/images/04425.jpg
#   inflating: data/images/02088.jpg
#   inflating: data/images/03143.jpg
#   inflating: data/images/01559.jpg
#   inflating: data/images/02115.jpg
#   inflating: data/images/02463.jpg
#   inflating: data/images/03737.jpg
#   inflating: data/images/02613.jpg
#   inflating: data/images/03325.jpg
#   inflating: data/images/02579.jpg
#   inflating: data/images/01329.jpg
#   inflating: data/images/01576.jpg
#   inflating: data/images/02817.jpg
#   inflating: data/images/00200.jpg
#   inflating: data/images/01035.jpg

# %%
dataset_root = "./data"
images_dir = "images"
image_filenames = sorted(os.listdir(os.path.join(dataset_root, images_dir)))
len(image_filenames)
# Out:
# 5729

# %% [markdown]
# # I. Image Generation (5 pts)
#
# Your first task is to solve a problem of generating photorealistic images out of noise (okay, this might sound optimistic).
#
# Namely, you are required to **create fake images of sneakers of resolution 28x28 given a vector of noise sampled from standard normal distribution.**

# %%
IMAGE_SIZE = (28, 28)

# %%
def img2data(image):
    data = 2 * image - 1
    return data

def data2img(data):
    image = 0.5 * data + 0.5
    return image

def load_image(filename, target_size=None):
    image_bgr = cv2.imread(os.path.join(dataset_root, images_dir, filename))
    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
    
    if target_size is not None:
        image_rgb = cv2.resize(image_rgb, target_size)

    image_rgb = (image_rgb / 255).astype(np.float32)
    return image_rgb

# %%
all_data = np.stack([
    img2data(load_image(fn, IMAGE_SIZE)) 
    for fn in tqdm.tqdm(image_filenames, position=0)
])
assert all_data.shape[1:] == IMAGE_SIZE + (3,)
# Out:
# 100%|██████████| 5729/5729 [00:04<00:00, 1396.38it/s]

# %%
def sample_data(batch_size):
    batch_ids = np.random.choice(len(all_data), size=batch_size)
    return all_data[batch_ids]

# %%
def visualize_images(data, n_rows, n_cols):
    n_samples = n_rows * n_cols

    if len(data) != n_samples:
        sample_indices = np.random.choice(len(data), n_samples, replace=len(data) < n_samples)
    else:
        sample_indices = np.arange(len(data)).astype(int)

    plt.figure(figsize=(int(2.5 * n_cols), int(2.5 * n_rows)))
    for i, sample_index in enumerate(sample_indices):
        plt.subplot(n_rows, n_cols, i + 1)
        plt.imshow(data2img(data[sample_index]))
        plt.axis("off")
    plt.show()

# draw random images
visualize_images(sample_data(32), 4, 8)

# %% [markdown]
# ## Random Noise
# Generate a TensorFlow `Tensor` containing gaussian noise of shape `[batch_size, dim]`:

# %%
NOISE_SIZE = 100

# %%
def sample_noise(batch_size):
    return np.random.randn(batch_size, NOISE_SIZE)

# %% [markdown]
# ## Fully connected GAN (1 pt)

# %% [markdown]
# ### Generator (0.5 pt)

# %% [markdown]
# Our first step is to build a generator. You should use the layers in `tf.keras.layers` to construct the model. All fully connected layers should include bias terms. Use the default initializers for parameters.
#
# Architecture:
#  * Fully connected with output size of 1024
#  * ReLU
#  * Fully connected with output size of 1024
#  * ReLU
#  * Fully connected with output size of 28 x 28 x 3
#  * Reshape into (28, 28, 3)
#  * TanH (to restrict every element of the output to be in the range [-1,1])

# %%
def build_fc_generator():
    inputs = L.Input(shape=(NOISE_SIZE,))

    X = inputs
    X = L.Dense(1024)(X)
    X = L.ReLU()(X)
    X = L.Dense(1024)(X)
    X = L.ReLU()(X)
    X = L.Dense(28 * 28 * 3)(X)
    X = L.Reshape((28, 28, 3))(X)
    X = L.Activation('tanh')(X)
    outputs = X

    return keras.models.Model(inputs=inputs, outputs=outputs, name="FCGAN_gen")

# %%
# Build FCGAN generator
generator = build_fc_generator()
generator.summary()
# Out:
# Model: "FCGAN_gen"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              103424
# _________________________________________________________________
# re_lu (ReLU)                 (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2352)              2410800
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28, 3)         0
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 3)         0
# =================================================================
# Total params: 3,563,824
# Trainable params: 3,563,824
# Non-trainable params: 0
# _________________________________________________________________

# %%
noise = sample_noise(32)
fake_data = generator.predict(noise)
assert fake_data.shape[1:] == IMAGE_SIZE + (3,)

# %% [markdown]
# ### Discriminator (0.5 pt)
#
# Now you are to build a discriminator. Same as for generator, all fully connected layers should include bias terms. You should use the default initializers for parameters here as well.
#
# Architecture:
#  * Flatten
#  * Fully connected with output size of 256
#  * Leaky ReLU(0.01)
#  * Fully connected with output size of 256
#  * Leaky ReLU(0.01)
#  * Fully connected with output size of 1
#  * Sigmoid (to obtain logits as an output)
#
# The output of the discriminator should thus have shape `[batch_size, 1]`, and contain real numbers corresponding to the probability that each of the `batch_size` inputs is a real image.

# %%
def build_fc_discriminator():
    inputs = L.Input(shape=IMAGE_SIZE + (3,))
    
    X = inputs
    X = L.Flatten()(X)
    X = L.Dense(256)(X)
    X = L.LeakyReLU(0.01)(X)
    X = L.Dense(256)(X)
    X = L.LeakyReLU(0.01)(X)
    X = L.Dense(1)(X)
    X = L.Activation('sigmoid')(X)
    outputs = X

    return keras.models.Model(inputs, outputs, name="FCGAN_disc")

# %%
# Build FCGAN discriminator
discriminator = build_fc_discriminator()
discriminator.summary()
# Out:
# Model: "FCGAN_disc"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28, 3)]       0
# _________________________________________________________________
# flatten (Flatten)            (None, 2352)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               602368
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 668,417
# Trainable params: 668,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
fake_probas = discriminator.predict(fake_data)
assert fake_probas.shape[1:] == (1,)

# %% [markdown]
# ## GAN Loss (1 pt)
#
# Compute the generator and discriminator loss. The generator loss is:
# $$\ell_G  =  -\mathbb{E}_{z \sim p(z)}\left[\log D(G(z))\right]$$
# and the discriminator loss is:
# $$ \ell_D = -\mathbb{E}_{x \sim p_\text{data}}\left[\log D(x)\right] - \mathbb{E}_{z \sim p(z)}\left[\log \left(1-D(G(z))\right)\right]$$
#
# Instead of computing the expectation, you may average over elements of the minibatch, so make sure to combine the loss by *averaging* instead of summing.
#
# Note that these are negated from the equations presented earlier as we will be *minimizing* these losses.

# %%
def generator_gan_loss(y_true, y_pred):
    fake_probas = y_pred
    logp_fake_is_real = K.log(fake_probas)
    loss = -K.mean(logp_fake_is_real)
    return loss

# %%
loss = generator_gan_loss(None, fake_probas)
assert loss.shape[1:] == ()
K.eval(loss)
# Out:
# 0.81599295

# %%
def discriminator_gan_loss(y_true, y_pred, eps=K.epsilon()):
    probas = K.clip(y_pred, eps, 1 - eps) # clip to avoid overflow
    
    is_real = y_true
    is_fake = 1 - y_true

    logp_real_is_real = is_real * K.log(probas)
    logp_fake_is_fake = is_fake * K.log(1 - probas)

    loss = -K.mean(logp_real_is_real) - K.mean(logp_fake_is_fake)
    return loss

# %%
real_data = sample_data(32)

real_and_fake_data = np.concatenate((real_data, fake_data))
real_and_fake_labels = [1] * len(real_data) + [0] * len(fake_data)

real_and_fake_probas = discriminator.predict(real_and_fake_data)

loss = discriminator_gan_loss(K.variable(real_and_fake_labels), K.variable(real_and_fake_probas))
assert loss.shape[1:] == ()
K.eval(loss)
# Out:
# 0.7086302

# %%
discriminator_opt = keras.optimizers.Adam(0.0002, 0.5)
discriminator_loss = discriminator_gan_loss

discriminator.compile(
    optimizer=discriminator_opt,
    loss=discriminator_loss
)

# %%
# we only want to be able to train generation for the combined model
discriminator.trainable = False

combined = keras.models.Model(
    inputs=generator.inputs,
    outputs=discriminator(generator.outputs),
    name="FCGAN_combined"
)

generator_opt = keras.optimizers.Adam(0.0002, 0.5,clipnorm=0.5)
generator_loss = generator_gan_loss

combined.compile(
    optimizer=generator_opt,
    loss=generator_loss
)

# %% [markdown]
# **Utility functions**
#
# Just a few helper functions that draw current data distributions and sample training batches.

# %%
def sample_images(n_rows, n_cols):
    batch_size = n_rows * n_cols
    data = generator.predict(sample_noise(batch_size))
    visualize_images(data, n_rows, n_cols)


def sample_probas(num_samples, batch_size=1):
    plt.title("Fake vs real distribution")
    
    real_probas, fake_probas = [], []
    
    for _ in range(0, num_samples, batch_size):
        real_data = sample_data(batch_size)
        fake_data = generator.predict(sample_noise(batch_size))
        
        real_probas.append(discriminator.predict(real_data))
        fake_probas.append(discriminator.predict(fake_data))

    real_probas = np.concatenate(real_probas, 0)[:num_samples]
    fake_probas = np.concatenate(fake_probas, 0)[:num_samples]

    plt.hist(real_probas, label="D(x)", color='g', alpha=0.5, range=[0,1])
    plt.hist(fake_probas, label="D(G(z))", color='r', alpha=0.5, range=[0,1])
    plt.legend(loc="best")
    plt.show()

# %% [markdown]
# ### Training
# Train generator and discriminator in a loop and draw results once every N iterations.

# %%
batch_size = 128
epochs = 5000

history = {"gen": [], "disc": []}

for epoch in tqdm.tqdm(range(epochs)):

    # Generate a new batch of noise
    noise = sample_noise(batch_size)

    # Get a batch of real images
    real_data = sample_data(batch_size)

    # Generate a batch of fake images
    # Hint: use .predict() method
    fake_data = generator.predict(noise)

    # Run discriminator on both real and fake images
    # Hint: use .train_on_batch() method
    loss_d_real = discriminator.train_on_batch(real_data, np.array([1.0] * batch_size)) # train on real_data
    loss_d_fake = discriminator.train_on_batch(fake_data, np.array([0.0] * batch_size)) # train on fake_data
    loss_d = 0.5 * (loss_d_real + loss_d_fake)

    # Make another noise batch
    noise = sample_noise(batch_size)

    # Train the generator to trick the discriminator
    # For the generator, we want all the {fake, not-fake} labels 
    # to say not-fake
    # Hint: use combined model
    loss_g = combined.train_on_batch(noise, np.array([1.0] * batch_size))

    history["disc"].append(loss_d)
    history["gen"].append(loss_g)

    if epoch % 100 == 0:
        clear_output(wait=True)
        print("Epoch:", epoch)
        
        sample_images(2, 4)
        sample_probas(100, batch_size)

        time = np.arange(epoch + 1)

        fig, ax = plt.subplots(ncols=2, figsize=(13, 4))
        ax[0].set_title("Generator loss")
        ax[0].plot(time, history["gen"], color='g')
        ax[1].set_title("Discriminator loss")
        ax[1].plot(time, history["disc"], color='r')
        plt.show()
# Out:
# Epoch: 4900
# 100%|██████████| 5000/5000 [04:46<00:00, 17.44it/s]

# %% [markdown]
# ## Deep Convolutional GANs (2 pts)
# In the first part of the notebook, you have implemented an almost direct copy of the original GAN network from Ian Goodfellow. However, this network architecture allows no real spatial reasoning. It is unable to reason about things like "sharp edges" in general because it lacks any convolutional layers. Thus, in this section, you are to implement some of the ideas from [DCGAN](https://arxiv.org/abs/1511.06434), where both discriminator and generator are convolutional networks.

# %% [markdown]
# ### Generator (1 pt)
#
# Architecture:
#  * Fully connected with output size of 128x7x7
#  * Reshape into (7, 7, 128)
#  * ReLU
#  * UpSampling2D(2)
#  * Conv2D: 3x3, filters=128, padding="same"
#  * Batch Normalization with momentum(0.8)
#  * ReLU
#  * UpSampling2D(2)
#  * Conv2D: 3x3, filters=64, padding="same"
#  * Batch Normalization with momentum(0.8)
#  * ReLU
#  * Conv2D: 3x3, filters=3, padding="same"
#  * TanH (to restrict every element of the output to be in the range [-1,1])

# %%
def build_dc_generator():
    inputs = L.Input(shape=(NOISE_SIZE,))

    X = inputs 
    X = L.Dense(7*7*128)(X)
    X = L.Reshape((7, 7, 128))(X)
    X = L.ReLU()(X)

    X = L.UpSampling2D(2)(X)
    X = L.Conv2D(128, (3, 3), padding='same')(X)
    X = L.BatchNormalization(momentum=0.8)(X)
    X = L.ReLU()(X)

    X = L.UpSampling2D(2)(X)
    X = L.Conv2D(64, (3, 3), padding='same')(X)
    X = L.BatchNormalization(momentum=0.8)(X)
    X = L.ReLU()(X)
    
    X = L.Conv2D(3, (3, 3), padding='same')(X)
    X = L.Activation('tanh')(X)
    outputs = X

    return keras.models.Model(inputs=inputs, outputs=outputs, name="DCGAN_gen")

# %%
# Build DCGAN generator
generator = build_dc_generator()
generator.summary()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "DCGAN_gen"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6272)              633472
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 14, 14, 128)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        73792
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 3)         1731
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 3)         0
# =================================================================
# Total params: 857,347
# Trainable params: 856,963
# Non-trainable params: 384
# _________________________________________________________________

# %%
noise = sample_noise(32)
fake_data = generator.predict(noise)
assert fake_data.shape[1:] == IMAGE_SIZE + (3,)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %% [markdown]
# ### Discriminator (1  pt)
#
# Architecture:
#  * Conv2D: 3x3, filters=32, strides=2, padding="same"
#  * Leaky ReLU(0.2)
#  * Dropout(0.25)
#  * Conv2D: 3x3, filters=64, strides=2, padding="same"
#  * Zero Padding: ((0, 1), (0, 1))
#  * Batch Normalization with momentum(0.8)
#  * Leaky ReLU(0.2)
#  * Dropout(0.25)
#  * Conv2D: 3x3, filters=128, strides=2, padding="same"
#  * Batch Normalization with momentum(0.8)
#  * Leaky ReLU(0.2)
#  * Dropout(0.25)
#  * Conv2D: 3x3, filters=256, strides=2, padding="same"
#  * Batch Normalization with momentum(0.8)
#  * Leaky ReLU(0.2)
#  * Dropout(0.25)
#  * Flatten
#  * Fully connected layer with output size 1
#  * Sigmoid

# %%
def build_dc_discriminator():
    inputs = L.Input(shape=(IMAGE_SIZE + (3,)))

    X = inputs
    X = L.Conv2D(32, (3, 3), strides=2, padding='same')(X)
    X = L.LeakyReLU(0.2)(X)
    X = L.Dropout(0.25)(X)

    X = L.Conv2D(64, (3, 3), strides=2, padding='same')(X)
    X = L.ZeroPadding2D(((0,1), (0, 1)))(X)
    X = L.BatchNormalization(momentum=0.8)(X)
    X = L.LeakyReLU(0.2)(X)
    X = L.Dropout(0.25)(X)

    X = L.Conv2D(128, (3, 3), strides=2, padding='same')(X)
    X = L.BatchNormalization(momentum=0.8)(X)
    X = L.LeakyReLU(0.2)(X)
    X = L.Dropout(0.25)(X)

    X = L.Conv2D(256, (3, 3), strides=2, padding='same')(X)
    X = L.BatchNormalization(momentum=0.8)(X)
    X = L.LeakyReLU(0.2)(X)
    X = L.Dropout(0.25)(X)
    
    X = L.Flatten()(X)
    X = L.Dense(1)(X)
    X = L.Activation('sigmoid')(X)
    
    outputs = X

    return keras.models.Model(inputs=inputs, outputs=outputs, name="DCGAN_disc")

# %%
# Build DCGAN discriminator
discriminator = build_dc_discriminator()
discriminator.summary()
# Out:
# Model: "DCGAN_disc"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 28, 28, 3)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 32)        896
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 8, 8, 64)          0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 2, 2, 256)         295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 256)         1024
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1025
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 391,233
# Trainable params: 390,337
# Non-trainable params: 896
# _________________________________________________________________

# %%
fake_probas = discriminator.predict(fake_data)
assert fake_probas.shape[1:] == (1,)

# %% [markdown]
# ## Least Squares GAN loss (1 pt)
# We'll now look at [Least Squares GAN loss](https://arxiv.org/abs/1611.04076), a newer, more stable alternative to the original GAN loss function. For this part, all you have to do is change the loss function and retrain the model. You'll implement equation (9) in the paper, with the generator loss:
# $$\ell_G  =  \frac{1}{2}\mathbb{E}_{z \sim p(z)}\left[\left(D(G(z))-1\right)^2\right]$$
# and the discriminator loss:
# $$ \ell_D = \frac{1}{2}\mathbb{E}_{x \sim p_\text{data}}\left[\left(D(x)-1\right)^2\right] + \frac{1}{2}\mathbb{E}_{z \sim p(z)}\left[ \left(D(G(z))\right)^2\right]$$

# %%
def generator_ls_loss(y_true, y_pred):
    # Implement Least Squares GAN loss for generator
    y_sq = K.pow(1 - y_pred, 2)
    loss = K.mean(y_sq) / 2
    return loss

# %%
loss = generator_ls_loss(None, K.variable(fake_probas))
assert loss.shape[1:] == ()
K.eval(loss)
# Out:
# 0.12465076

# %%
def discriminator_ls_loss(y_true, y_pred):
    # Implement Least Squares GAN loss for discriminator
    is_real = y_true
    is_fake = 1 - y_true

    sq_err_real_and_1 = is_real * K.pow(y_pred - 1, 2)
    sq_err_fake_and_0 = is_fake * K.pow(y_pred, 2)

    loss = (K.mean(sq_err_real_and_1) + K.mean(sq_err_fake_and_0)) / 2
    return loss

# %%
real_data = sample_data(32)

real_and_fake_data = np.concatenate((real_data, fake_data))
real_and_fake_labels = np.array([1] * len(real_data) + [0] * len(fake_data))

real_and_fake_probas = discriminator.predict(real_and_fake_data)

loss = discriminator_ls_loss(K.variable(real_and_fake_labels), K.variable(real_and_fake_probas))
assert loss.shape[1:] == ()
K.eval(loss)
# Out:
# 0.12501918

# %% [markdown]
# Last step is to complile models with proper optimizers and losses:

# %%
discriminator_opt = keras.optimizers.Adam(0.0002, 0.5)
discriminator_loss = discriminator_ls_loss

discriminator.compile(
    optimizer=discriminator_opt,
    loss=discriminator_loss
)

# %%
# we only want to be able to train generation for the combined model
discriminator.trainable = False

combined = keras.models.Model(
    inputs=generator.inputs,
    outputs=discriminator(generator.outputs),
    name="DCGAN_combined"
)

generator_opt = keras.optimizers.Adam(0.0002, 0.5, clipnorm=0.5)
generator_loss = generator_ls_loss

combined.compile(
    optimizer=generator_opt,
    loss=generator_loss
)

# %% [markdown]
# ### Training
#
# Here, training loop is identical to the one for FCGAN in the previous task:

# %%
batch_size = 128
epochs = 5000

history = {"gen": [], "disc": []}

for epoch in range(epochs):

    # Generate a new batch of noise
    noise = sample_noise(batch_size)

    # Get a batch of real images
    real_data = sample_data(batch_size)

    # Generate a batch of fake images
    # Hint: use .predict() method
    fake_data = generator.predict(noise)

    # Run discriminator on both real and fake images
    # Hint: use .train_on_batch() method
    loss_d_real = discriminator.train_on_batch(real_data, np.array([1.0] * batch_size)) # train on real_data
    loss_d_fake = discriminator.train_on_batch(fake_data, np.array([0.0] * batch_size)) # train on fake_data
    loss_d = 0.5 * (loss_d_real + loss_d_fake)

    # Make another noise batch
    noise = sample_noise(batch_size)

    # Train the generator to trick the discriminator
    # For the generator, we want all the {fake, not-fake} labels 
    # to say not-fake
    # Hint: use combined model
    loss_g = combined.train_on_batch(noise, np.array([1.0] * batch_size))

    history["disc"].append(loss_d)
    history["gen"].append(loss_g)

    if epoch % 100 == 0:
        clear_output(wait=True)
        print("Epoch:", epoch)
        
        sample_images(2, 4)
        sample_probas(100, batch_size)

        time = np.arange(epoch + 1)

        fig, ax = plt.subplots(ncols=2, figsize=(13, 4))
        ax[0].set_title("Generator loss")
        ax[0].plot(time, history["gen"], color='g')
        ax[1].set_title("Discriminator loss")
        ax[1].plot(time, history["disc"], color='r')
        plt.show()
# Out:
# Epoch: 4900
# /tensorflow-1.15.2/python3.6/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'

# %% [markdown]
# Save some generated images for evaluation:

# %%
all_fake_data = []
for _ in range(0, len(all_data), batch_size):
    fake_data = generator.predict(sample_noise(batch_size))
    all_fake_data.append(fake_data)

all_fake_data = np.concatenate(all_fake_data, 0)[:len(all_data)]
assert all_fake_data.shape == all_data.shape

# %%
visualize_images(all_fake_data, 4, 8)

# %%
np.save("fake_data.npy", all_fake_data)

# %% [markdown]
# # II. Super Resolution (3 pts)
#
# In this part of the notebook you will train a generative model that solves an image-to-image problem, with "small images" as a source domain and "large images" being a target domain.
#
# To specify the task, you are to **scale small images of 28x28 pixels up to size of 112x112 pixels**.

# %%
LOW_RES_SIZE = IMAGE_SIZE
HIGH_RES_SIZE = (112, 112)

# %%
all_data_hr = np.stack([
    img2data(load_image(fn, HIGH_RES_SIZE))
    for fn in tqdm.tqdm(image_filenames, position=0)
])
assert all_data_hr.shape[1:] == HIGH_RES_SIZE + (3,)
# Out:
# 100%|██████████| 5729/5729 [00:05<00:00, 1106.87it/s]

# %%
def sample_super_res_data(batch_size, low_res_size=LOW_RES_SIZE, high_res_size=HIGH_RES_SIZE):
    batch_ids = np.random.choice(len(all_data), size=batch_size)
    return all_data[batch_ids], all_data_hr[batch_ids]

# %%
batch_size = 4
real_data_lr, real_data_hr = sample_super_res_data(batch_size)

assert real_data_lr.shape[1:] == LOW_RES_SIZE + (3,)
assert real_data_hr.shape[1:] == HIGH_RES_SIZE + (3,)

plt.figure(figsize=(8, 14))
for i in range(batch_size):
    plt.subplot(batch_size, 2, 2 * i + 1)
    plt.title("Low resolution")
    plt.imshow(data2img(real_data_lr[i]))
    plt.axis("off")

    plt.subplot(batch_size, 2, 2 * i + 2)
    plt.title("High resolution")
    plt.imshow(data2img(real_data_hr[i]))
    plt.axis("off")

plt.show()

# %% [markdown]
# In the second part of this task, you are to train an [SRGAN](https://arxiv.org/abs/1609.04802)-like model. For your convinience, some layers are already implemented. Now it's your turn -- fill the gaps so the model passes the asserts below.

# %% [markdown]
# ### Generator (1.5 pts)

# %% [markdown]
# To build a SRGAN Generator, you will need a basic Residual Block(filters):
#
# * Conv2D: 3x3, filters=filters, strides=1, padding="same"
# * ReLU
# * Batch Normalization with momentum(0.8)
# * Conv2D: 3x3, filters=filters, strides=1, padding="same"
# * Batch Normalization with momentum(0.8)
# * Sum up outputs with inputs

# %%
def residual_block(inputs, filters, **kwargs):
    
    # TODO: build the model
    X = inputs
    X = L.Conv2D(filters=filters, kernel_size=3, strides=1, padding = 'same')(X)
    X = L.ReLU()(X)
    X = L.BatchNormalization(momentum=0.8)(X)
    X = L.Conv2D(filters=filters, kernel_size=3, strides=1, padding = 'same')(X)
    X = L.BatchNormalization(momentum=0.8)(X)
    outputs = X
    res_output = keras.layers.add([inputs, outputs])

    #outputs = keras.activations.tanh(model)
    #outputs.summary()
    
    return res_output

# %% [markdown]
# ... and an Upsampling Block(filters):
#
# * UpSampling2D(2)
# * Conv2D: 3x3, filters=filters, strides=1, padding="same"
# * ReLU

# %%
def up_block(inputs, filters, **kwargs):
    
    # TODO: build the block
    X = inputs
    X = L.UpSampling2D(2)(X)
    X = L.Conv2D(filters=filters, kernel_size=3, strides=1, padding = 'same')(X)
    X = L.ReLU()(X)
    outputs = X

    return outputs

# %% [markdown]
# Now, using these basic building blocks, one is able to define a SRGAN generator:

# %%
def build_sr_generator():
    inputs = L.Input(shape=LOW_RES_SIZE + (3,))

    # An initial conv block
    x = L.Conv2D(64, kernel_size=9, strides=1, padding="same")(inputs)
    x = L.ReLU()(x)

    conv = x

    # 16 residual blocks with filters=64
    for block_num in range(16):
        x = residual_block(x, 64)

    # A post-residual block
    x = L.Conv2D(64, kernel_size=3, strides=1, padding="same")(x)
    x = L.BatchNormalization(momentum=0.8)(x)

    # Sum up current 'x' with 'conv' obtained earlier
    x = keras.layers.add([conv, x])

    # Two upsampling blocks with filters=256
    x = up_block(up_block(x, 256), 256)

    # Final conv block
    x = L.Conv2D(3, kernel_size=9, strides=1, padding="same")(x)
    outputs = L.Activation("tanh")(x)
    
    return keras.models.Model(inputs=inputs, outputs=outputs, name="SRGAN_gen")

# %%
# Build SRGAN generator
K.clear_session()
generator = build_sr_generator()
generator.summary()
# Out:
# Model: "SRGAN_gen"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 64)   15616       input_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 28, 28, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 64)   36928       re_lu_1[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 28, 28, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 64)   256         re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 64)   36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 64)   0           re_lu_1[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 64)   36928       add_1[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 28, 28, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 64)   256         re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 64)   36928       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 64)   0           add_1[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 64)   36928       add_2[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 28, 28, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 64)   256         re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 64)   36928       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 64)   0           add_2[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 64)   36928       add_3[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 28, 28, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 64)   256         re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 64)   36928       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 64)   0           add_3[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 64)   36928       add_4[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 28, 28, 64)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 64)   256         re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 64)   0           add_4[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 64)   36928       add_5[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 28, 28, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 28, 28, 64)   256         re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 28, 28, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 64)   0           add_5[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 64)   36928       add_6[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 28, 28, 64)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 28, 28, 64)   256         re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 64)   0           add_6[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 64)   36928       add_7[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 28, 28, 64)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 64)   256         re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 28, 28, 64)   0           add_7[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 64)   36928       add_8[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 28, 28, 64)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 64)   256         re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 28, 28, 64)   0           add_8[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 64)   36928       add_9[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 28, 28, 64)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 64)   256         re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 28, 28, 64)   0           add_9[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 64)   36928       add_10[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 28, 28, 64)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 64)   256         re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 28, 28, 64)   0           add_10[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 64)   36928       add_11[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 28, 28, 64)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 64)   256         re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 28, 28, 64)   0           add_11[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 64)   36928       add_12[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 28, 28, 64)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 64)   256         re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 28, 28, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 28, 28, 64)   0           add_12[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 64)   36928       add_13[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 28, 28, 64)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 28, 28, 64)   256         re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 28, 28, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 28, 28, 64)   0           add_13[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 28, 28, 64)   36928       add_14[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 28, 28, 64)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 28, 28, 64)   256         re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 28, 28, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 28, 28, 64)   0           add_14[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 28, 28, 64)   36928       add_15[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 28, 28, 64)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 28, 28, 64)   256         re_lu_17[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 28, 28, 64)   36928       batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 28, 28, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 28, 28, 64)   0           add_15[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 28, 28, 64)   36928       add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 28, 28, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 28, 28, 64)   0           re_lu_1[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 56, 56, 64)   0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 56, 56, 256)  147712      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 56, 56, 256)  0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 112, 112, 256 0           re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 112, 112, 256 590080      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 112, 112, 256 0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 112, 112, 3)  62211       re_lu_19[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 3)  0           conv2d_37[0][0]
# ==================================================================================================
# Total params: 2,042,691
# Trainable params: 2,038,467
# Non-trainable params: 4,224
# __________________________________________________________________________________________________

# %%
real_data_lr, real_data_hr = sample_super_res_data(32)
fake_data_hr = generator.predict(real_data_lr)
assert fake_data_hr.shape[1:] == HIGH_RES_SIZE + (3,)

# %% [markdown]
# ### Discriminator (1.5 pts)

# %% [markdown]
# First, define a Discriminator Block(filters, strides):
#
# * Conv2D: 3x3, filters=filters, strides=strides, padding="same"
# * Leaky ReLU(0.2)
# * (optional) Batch Normalization with momentum(0.8)

# %%
def d_block(inputs, filters, strides=1, apply_batchnorm=False, **kwargs):
    X = inputs
    X = L.Conv2D(filters, kernel_size=3, strides=strides, padding = 'same')(X)
    X = L.LeakyReLU(0.2)(X)
    if apply_batchnorm:
        X = L.BatchNormalization()(X)
    outputs = X
    return outputs

# %% [markdown]
# Now, use this block to build up SRGAN discriminator:
#
# * DBlock(filters=64, strides=1) with Batch Normalization
# * DBlock(filters=64, strides=2)
# * DBlock(filters=128, strides=1)
# * DBlock(filters=128, strides=2)
# * DBlock(filters=256, strides=1)
# * DBlock(filters=256, strides=2)
# * DBlock(filters=512, strides=1)
# * DBlock(filters=512, strides=2)
# * Flatten
# * Fully connected with output size of 1024
# * Leaky ReLU(0.2)
# * Fully connected with output size of 1
# * Sigmoid

# %%
def build_sr_discriminator():
    inputs = L.Input(shape=HIGH_RES_SIZE + (3,))

    X = inputs
    X = d_block(X, 64, 1, True)
    X = d_block(X, 64, 2)
    X = d_block(X, 128, 1)
    X = d_block(X, 128, 2)

    X = d_block(X, 256, 1)
    X = d_block(X, 256, 2)

    X = d_block(X, 512, 1)
    X = d_block(X, 512, 2)

    X = L.Flatten()(X)
    X = L.Dense(1024)(X)
    X = L.LeakyReLU(0.2)(X)
    X = L.Dense(1)(X)
    X = L.Activation('sigmoid')(X)
    outputs = X

    return keras.models.Model(inputs=inputs, outputs=outputs, name="SRGAN_disc")

# %%
# Build SRGAN discriminator
discriminator = build_sr_discriminator()
discriminator.summary()
# Out:
# Model: "SRGAN_disc"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 112, 112, 3)       0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 112, 112, 64)      1792
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 112, 112, 64)      0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 56, 56, 128)       73856
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 28, 28, 256)       295168
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 14, 14, 256)       590080
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 14, 14, 512)       1180160
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              25691136
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1025
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 30,377,793
# Trainable params: 30,377,665
# Non-trainable params: 128
# _________________________________________________________________

# %%
fake_probas = discriminator.predict(fake_data_hr)
assert fake_probas.shape[1:] == (1,)

# %%
real_data_lr, real_data_hr = sample_super_res_data(32)
real_probas = discriminator.predict(real_data_hr)

real_data = sample_data(32)

real_and_fake_data_hr = np.concatenate((real_data_hr, fake_data_hr))
real_and_fake_labels = np.array([1] * len(real_data_hr) + [0] * len(fake_data_hr))

real_and_fake_probas = discriminator.predict(real_and_fake_data_hr)

loss = discriminator_ls_loss(K.variable(real_and_fake_labels), K.variable(real_and_fake_probas))
assert loss.shape[1:] == ()
K.eval(loss)
# Out:
# 0.12500766

# %% [markdown]
# Typically, SRGAN is trained with additional loss on features from pretrained VGG-19. However, you task will be a bit simplier: use **mean squared error** between real and fake data instead.

# %%
from keras.applications.vgg19 import VGG19
from keras.applications.vgg19 import preprocess_input

# %%
model = VGG19(
    weights='imagenet',
    include_top=False,
    input_shape=HIGH_RES_SIZE+(3,)
)
model.trainable = False
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
def feature_loss(real_features, fake_features):
    # Implement MSE
    image1 = model(real_features)
    image2 = model(fake_features)
    loss = K.mean(K.square(image1 - image2))
    return loss

# %%
loss = feature_loss(K.variable(real_data_hr), K.variable(fake_data_hr))
assert loss.shape == ()
K.eval(loss)
# Out:
# 0.20348571

# %%
discriminator_opt = keras.optimizers.Adam(1e-3, 0.5, clipnorm=1.5)
discriminator_loss = 'binary_crossentropy'# you may choose any or try both. 
#By default, opt for the Least Squares GAN loss.

discriminator.compile(
    optimizer=discriminator_opt,
    loss=discriminator_loss
)

# %%
# we only want to be able to train generation for the combined model

discriminator2 = keras.engine.network.Network(
    inputs=discriminator.inputs,
    outputs=discriminator.outputs,
)
discriminator2.trainable = False


inputs2 = L.Input(LOW_RES_SIZE+(3,))
outputs2 = generator(inputs2)

combined = keras.models.Model(
    inputs=inputs2,
    outputs=[discriminator2(outputs2), outputs2], # you should return both probas AND generated images
    name="SRGAN_combined"
)

generator_opt = keras.optimizers.Adam(2e-4, 0.5, clipnorm=1.5)
generator_loss = ['binary_crossentropy', feature_loss] # mind the order of outputs -- it should match the losses
loss_weights = [0.005, 1]

combined.compile(
    optimizer=generator_opt,
    loss=generator_loss,
    loss_weights=loss_weights
)

# %%
def sample_images(n_samples):
    batch_size = n_samples
    real_data_lr, real_data_hr = sample_super_res_data(batch_size)
    fake_data_hr = generator.predict(real_data_lr)

    plt.figure(figsize=(11, int(3.5 * n_samples)))
    for i in range(batch_size):
        plt.subplot(n_samples, 3, 3 * i + 1)
        plt.title("Original LR")
        plt.imshow(data2img(real_data_lr[i]))
        plt.axis("off")

        plt.subplot(n_samples, 3, 3 * i + 3)
        plt.title("Generated HR")
        plt.imshow(data2img(fake_data_hr[i]))
        plt.axis("off")
        
        plt.subplot(n_samples, 3, 3 * i + 2)
        plt.title("Real HR")
        plt.imshow(data2img(real_data_hr[i]))
        plt.axis("off")

    plt.show()


def sample_probas(num_samples, batch_size):
    plt.title("Fake vs real distribution")
    
    real_probas, fake_probas = [], []

    for i in range(0, num_samples, batch_size):
        real_data_lr, real_data_hr = sample_super_res_data(batch_size)
        fake_data_hr = generator.predict(real_data_lr)
        
        real_probas.append(discriminator.predict(real_data_hr))
        fake_probas.append(discriminator.predict(fake_data_hr))

    real_probas = np.concatenate(real_probas, 0)[:num_samples]
    fake_probas = np.concatenate(fake_probas, 0)[:num_samples]

    plt.hist(real_probas, label="D(x)", alpha=0.5, range=[0,1], color='g')
    plt.hist(fake_probas, label="D(G(z))", alpha=0.5, range=[0,1], color='r')
    plt.legend(loc="best")
    plt.show()

# %% [markdown]
# ### Training

# %%
# %cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
batch_size = 16
epochs = 50000

history = {"gen": [], "disc": []}

for epoch in tqdm.tqdm(range(epochs)):

    # Sample low-res and high-res data
    real_data_lr, real_data_hr = sample_super_res_data(batch_size)

    # Generate high resolution images from low resolution ones
    fake_data_hr = generator.predict(real_data_lr)

    # Run discriminator on both real and fake high resolution images
    loss_d_real = discriminator.train_on_batch(real_data_hr, np.array([1.0] * batch_size) - np.random.random_sample(batch_size) * 0.2) # train on real_data_hr
    loss_d_fake = discriminator.train_on_batch(fake_data_hr, np.array([0.0] * batch_size)) # train on fake_data_hr
    loss_d = 0.5 * (loss_d_real + loss_d_fake)

    # Sample another batch of low-res and high-res data
    real_data_lr, real_data_hr = sample_super_res_data(batch_size)

    # Train the generator to trick the discriminator
    # For the generator, we want all the {fake, not-fake} labels 
    # to say not-fake
    # Mind the number and the order of the outputs of the combined model!
    loss_g = combined.train_on_batch(real_data_lr, [np.array([1.0] * batch_size), real_data_hr])

    history["gen"].append(loss_g) 
    history["disc"].append(loss_d)

    if epoch % 1000 == 0:
            discriminator.save_weights('discriminator.hdf5')
            generator.save_weights('generator.hdf5')
    if epoch % 100 == 0:
        clear_output(wait=True)
        print("Epoch:", epoch)
        
        sample_images(4)
        sample_probas(100, batch_size)

        time = np.arange(epoch + 1)

        fig, ax = plt.subplots(ncols=2, figsize=(13, 4))
        ax[0].set_title("Generator loss")
        ax[0].plot(time, [_[0] for _ in history["gen"]], color="dodgerblue", label="GAN loss")
        ax[0].plot(time, [_[1] for _ in history["gen"]], color="gold", label="Feature loss")
        ax[0].plot(time, [_[2] for _ in history["gen"]], color='g', label="Total loss")
        ax[0].legend(loc="upper left")
        ax[1].set_title("Discriminator loss")
        ax[1].plot(time, history["disc"], color='r')
        

        plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Save some fake high resolution images generated from real low resolution samples stored in `all_data`:

# %%
generator = build_sr_generator()
generator.load_weights('generator (1).hdf5')
discriminator = build_sr_discriminator()
discriminator.load_weights('discriminator (1).hdf5')

# %%
generator is None
# Out:
# False

# %%
all_fake_data_from_real_lr = []
for index in tqdm.trange(0, len(all_data), batch_size, position=0):
    real_data_lr, real_data_hr = sample_super_res_data(batch_size) 
    fake_data_hr = generator.predict(real_data_lr)
    all_fake_data_from_real_lr.append(fake_data_hr)

all_fake_data_from_real_lr = np.concatenate(all_fake_data_from_real_lr, 0)[:len(all_data)]
assert all_fake_data_from_real_lr.shape == all_data_hr.shape
# Out:
# 100%|██████████| 359/359 [00:23<00:00, 16.43it/s]
#
#
# 100%|██████████| 359/359 [00:23<00:00, 15.18it/s]

# %%
visualize_images(all_fake_data_from_real_lr, 4, 8)

# %%
np.save("fake_data_from_real_lr.npy", all_fake_data_from_real_lr)

# %% [markdown]
# Now save some fake high resolution images generated from fake low resolution samples stored in `all_fake_data`:

# %%
try:
    all_fake_data
except:
    all_fake_data = np.load("fake_data.npy")

# %%
all_fake_data_from_fake_lr = []
for index in tqdm.trange(0, len(all_data), batch_size, position=0):
    fake_data_lr = all_fake_data[index:index + batch_size]
    fake_data_hr = generator.predict(fake_data_lr)
    all_fake_data_from_fake_lr.append(fake_data_hr)

all_fake_data_from_fake_lr = np.concatenate(all_fake_data_from_fake_lr, 0)[:len(all_data)]
assert all_fake_data_from_fake_lr.shape == all_data_hr.shape
# Out:
# 100%|█████████▉| 358/359 [00:21<00:00, 16.40it/s]
# 100%|██████████| 359/359 [00:21<00:00, 16.34it/s]

# %%
visualize_images(all_fake_data_from_fake_lr, 4, 8)

# %%
np.save("fake_data_from_fake_lr.npy", all_fake_data_from_fake_lr)

# %% [markdown]
# # III. GAN metrics (2 pts)
#
# There exists a few metrics used to measure GAN performance. Some of them are based on comparing real samples against generated ones, while the other rely on additional pretrained models that are applied to both real and generated data in order to accumulate high-level statistics. In this task, you are going to use two metrics representing these two approaches -- namely, [Precision-Recall Density](https://arxiv.org/pdf/1806.00035) and [Fréchet Inception Distance](https://arxiv.org/pdf/1706.08500).

# %% [markdown]
# ### Precision-Recall Density (PRD score) (1 pt)
#
# Your first task is to implement [Precision-Recall Density](https://arxiv.org/pdf/1806.00035.pdf) score.

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans

def bin_counts(real_data, fake_data, n_bins=25):
    real_data = real_data.reshape(len(real_data), -1)
    fake_data = fake_data.reshape(len(fake_data), -1)

    data = np.vstack([real_data, fake_data])

    kmeans = MiniBatchKMeans(n_clusters=n_bins, n_init=10).fit(data)
    
    real_labels = kmeans.labels_[:len(real_data)]
    fake_labels = kmeans.labels_[len(real_data):]

    real_density = np.histogram(real_labels, bins=n_bins, range=[0, n_bins], density=True)[0]
    fake_density = np.histogram(fake_labels, bins=n_bins, range=[0, n_bins], density=True)[0]
    
    return real_density, fake_density

# %%
import math
from sklearn.metrics import auc

def calculate_alpha_beta(real_density, fake_density, n_thetas=1000):
    assert real_density.shape == fake_density.shape
    
    alpha = []
    beta = []
    
    thetas = np.linspace(1e-6, np.pi / 2 - 1e-6, num=n_thetas)
    for theta in thetas:
        tan = math.tan(theta)
        alpha.append(np.sum(np.minimum(real_density * tan, fake_density), axis=-1))
        beta.append(alpha[-1] / tan)
    
    return alpha, beta

def calculate_precision_recall_density(real_densities, fake_densities, repeat_number=1000):
    vectors = np.array([
       calculate_alpha_beta(real_densities, fake_densities)
       for _ in range(repeat_number)
    ]).mean(axis=0)
    return vectors


def calculate_prd_score(real_data, fake_data):
    # Calculate bin counts from real and generated data
    real_density, fake_density = bin_counts(real_data, fake_data)

    plt.bar(range(len(real_density)), real_density, width=1, color='g', alpha=0.5, label="Real density")
    plt.bar(range(len(fake_density)), fake_density, width=1, color='r', alpha=0.5, label="Fake density")
    plt.legend()
    plt.show()

    # Calculate alpha and beta
    alpha, beta = calculate_alpha_beta(real_density, fake_density)
    
    # Calculate area under curve (AUC) for alpha and beta
    score = auc(alpha, beta)

    return score, alpha, beta

# %% [markdown]
# Calculate PRD score for DCGAN (task I). You should pass `all_data` and `all_fake_data` to scoring function.

# %%
score,  _, _ = calculate_prd_score(all_data, all_fake_data)
print("Score:", score)
# Out:
# (1000,)
# (1000,)
# Score: 0.9699058323406098

# %% [markdown]
# Now use PRD score to compare high resolution data generated from real low resolution data (`all_fake_data_from_real_lr`) and fake resolution data (`all_fake_data_from_fake_lr`):

# %%
print("Generated from real LR")
score_real, alpha_real, beta_real = calculate_prd_score(all_data_hr, all_fake_data_from_real_lr)
print("Score:", score_real, end='\n\n')

print("Generated from fake LR")
score_fake, alpha_fake, beta_fake = calculate_prd_score(all_data_hr, all_fake_data_from_fake_lr)
print("Score:", score_fake, end='\n\n')

fig, ax = plt.subplots(figsize=(8, 8))
ax.tick_params(axis="both", which="major", labelsize=8)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.plot(alpha_real, beta_real, color='g', label="Generated from real LR")
plt.plot(alpha_fake, beta_fake, color='r', label="Generated from fake LR")
plt.legend()
plt.show()
# Out:
# Generated from real LR
# (1000,)
# (1000,)
# Score: 0.9624360673656868
#
# Generated from fake LR
# (1000,)
# (1000,)
# Score: 0.9246859190695355

# %% [markdown]
# ### Fréchet Inception Distance (FID score) (1 pt)
#
# [Frechet Inception Distance](https://arxiv.org/pdf/1706.08500) is an improved version of [Inception score](https://arxiv.org/abs/1606.03498), that additionally calculates the statistics of real data and compares it to the statistics of generated data. It is probably the most widely-used option for evaluating GANs, and relies on features extracted with [InceptionV3](https://arxiv.org/abs/1512.00567) pretrained on ImageNet. These features assumed to come from a multivariate Gaussian distribution, so Fréchet distance between two multivariate Gaussians can be calculated:
#
# $$\text{FID} = ||\mu_r - \mu_g||^2 + \text{Tr} (\Sigma_r + \Sigma_g - 2 (\Sigma_r \Sigma_g)^{1/2}),$$
#
# where $X_r \sim \mathcal{N} (\mu_r, \Sigma_r)$ and $X_g \sim \mathcal{N} (\mu_g, \Sigma_g)$ are the 2048-dimensional activations of the Inception-v3 pool3 layer for real and generated samples respectively.

# %% [markdown]
# First, create InceptionV3 model. As you will be using it for feature extraction only, you should set `include_top=False` and `pooling="avg"`:

# %%
base_inception = keras.applications.inception_v3.InceptionV3(weights="imagenet",
                                                             include_top=False,
                                                             pooling='avg')
inputs = L.Input(shape=(112, 112, 3))
outputs = base_inception(L.UpSampling2D(2)(inputs))

inception = keras.models.Model(inputs=inputs, outputs=outputs)
inception.trainable = False
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
real_data_lr, real_data_hr = sample_super_res_data(32)
assert inception.predict(real_data_hr).shape[1:] == (2048,)

# %%
def calculate_activations(data, batch_size=32, verbose=False):
    # Calculate activations of Pool3 layer of InceptionV3
    if verbose:
        print("Calculating activations...")
    activations = inception.predict(data, batch_size=batch_size, verbose=verbose)
    return activations

def calculate_activation_statistics(activations):
    # Calculate mean and covariance of activations. Mind the dimensions!
    mu = np.mean(activations, axis=0)
    sigma = np.cov(activations.T)
    return mu, sigma

# %%
real_activations = calculate_activations(all_data_hr, verbose=True)
real_mu, real_sigma = calculate_activation_statistics(real_activations)

assert real_mu.shape == (2048,)
assert real_sigma.shape == (2048, 2048)
# Out:
# Calculating activations...
# 5729/5729 [==============================] - 15s 3ms/step

# %%
import scipy

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    assert mu1.shape == mu2.shape
    assert sigma1.shape == sigma2.shape

    sigma1_sigma2 = scipy.linalg.sqrtm(np.dot(sigma1, sigma2))

    # Numerical error might give slight imaginary component
    if np.iscomplexobj(sigma1_sigma2):
        sigma1_sigma2 = sigma1_sigma2.real

    # Product might be almost singular
    if not np.isfinite(sigma1_sigma2).all():
        offset = np.eye(sigma1.shape[0]) * eps
        sigma1_sigma2 = scipy.linalg.sqrtm(np.dot(sigma1 + offset, sigma2 + offset))

    diff = scipy.linalg.norm(mu1 - mu2)
    return diff ** 2 + np.trace(sigma1 + sigma2 - 2 * sigma1_sigma2) # use diff, sigma1, sigma2 to calculate FID according to the formula above


def calculate_fid_score(real_data, fake_data, verbose=False):
    # Run inception on real and fake data to obtain activations
    real_activations = calculate_activations(real_data)
    fake_activations = calculate_activations(fake_data)

    # Calculate mu and sigma for both real and fake activations
    real_mu, real_sigma = calculate_activation_statistics(real_activations)
    fake_mu, fake_sigma = calculate_activation_statistics(fake_activations)

    return calculate_frechet_distance(real_mu, real_sigma, fake_mu, fake_sigma) # calculate Frechet distance

# %% [markdown]
# Calculate FID score between `all_data_hr` and `all_fake_data_from_real_hr`:

# %%
score = calculate_fid_score(all_data_hr, all_fake_data_from_real_lr)
print("Score:", score)
# Out:
# Score: 80.6887725287642

# %% [markdown]
# Putting it all together: calculate FID score between `all_data_hr` and `all_fake_data_from_fake_hr`:

# %%
score = calculate_fid_score(all_data_hr, all_fake_data_from_fake_lr)
print("Score:", score)
# Out:
# Score: 151.46321212282962
